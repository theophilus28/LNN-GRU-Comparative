# %%
# 1 Library setup
import os
import glob
import numpy as np
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge


DATA_DIR = "data/data"
OUT_DIR = "icu_batches"
MERGED_PATH = "icu_merged.parquet"

BIN_HOURS = 12
BATCH_SIZE = 3000

os.makedirs(OUT_DIR, exist_ok=True)

# %%
# 2 Load data and setup metadata

icustays = pd.read_csv(f"{DATA_DIR}/ICUSTAYS.csv")
admissions = pd.read_csv(f"{DATA_DIR}/ADMISSIONS.csv")
patients = pd.read_csv(f"{DATA_DIR}/PATIENTS.csv")

icu_meta = (
    icustays
    .merge(admissions, on=["SUBJECT_ID", "HADM_ID"], how="left")
    .merge(patients, on="SUBJECT_ID", how="left")
)

icu_meta = icu_meta[[
    "SUBJECT_ID",
    "HADM_ID",
    "ICUSTAY_ID",
    "INTIME",
    "OUTTIME"
]]

icu_meta["INTIME"] = pd.to_datetime(icu_meta["INTIME"])
icu_meta["OUTTIME"] = pd.to_datetime(icu_meta["OUTTIME"])


# I am no longer calling this, as we are running into the issue of somehow the icustay_ids with missing 
# out times are also missing from our computed out time results, but the code may prove useful later
def compute_last_event_time():
    last_times = []

    # CHARTEVENTS
    ce = pd.read_csv(
        f"{DATA_DIR}/CHARTEVENTS.csv",
        usecols=["ICUSTAY_ID", "CHARTTIME"]
    )
    ce["CHARTTIME"] = pd.to_datetime(ce["CHARTTIME"])
    last_times.append(
        ce.groupby("ICUSTAY_ID")["CHARTTIME"].max()
    )

    # INPUTEVENTS_MV
    ie = pd.read_csv(
        f"{DATA_DIR}/INPUTEVENTS_MV.csv",
        usecols=["ICUSTAY_ID", "ENDTIME"]
    )
    ie["ENDTIME"] = pd.to_datetime(ie["ENDTIME"])
    last_times.append(
        ie.groupby("ICUSTAY_ID")["ENDTIME"].max()
    )

    # OUTPUTEVENTS
    oe = pd.read_csv(
        f"{DATA_DIR}/OUTPUTEVENTS.csv",
        usecols=["ICUSTAY_ID", "CHARTTIME"]
    )
    oe["CHARTTIME"] = pd.to_datetime(oe["CHARTTIME"])
    last_times.append(
        oe.groupby("ICUSTAY_ID")["CHARTTIME"].max()
    )

    # PRESCRIPTIONS
    pr = pd.read_csv(
        f"{DATA_DIR}/PRESCRIPTIONS.csv",
        usecols=["ICUSTAY_ID", "ENDDATE"]
    )
    pr["ENDDATE"] = pd.to_datetime(pr["ENDDATE"])
    last_times.append(
        pr.groupby("ICUSTAY_ID")["ENDDATE"].max()
    )

    # Combine all
    all_last = pd.concat(last_times, axis=1)
    return all_last.max(axis=1)  # row-wise max


print("Missing outtime:", icu_meta["OUTTIME"].isna().sum())
icu_meta = icu_meta.dropna(subset=["OUTTIME"]).reset_index(drop=True)
assert icu_meta["OUTTIME"].notna().all()
assert (icu_meta["OUTTIME"] > icu_meta["INTIME"]).all()
# Out:
# Missing outtime: 10

# %%
# 3 create structure for bins

def build_base_grid(batch_meta):
    rows = []
    for _, r in batch_meta.iterrows():
        n_bins = int(
            np.ceil(
                (r.OUTTIME - r.INTIME).total_seconds()
                / (BIN_HOURS * 3600)
            )
        )
        for b in range(n_bins):
            rows.append({
                "SUBJECT_ID": r.SUBJECT_ID,
                "ICUSTAY_ID": r.ICUSTAY_ID,
                "bin": b
            })
    return pd.DataFrame(rows)

# %%
# 4 obtain desired vitals info from chartevents

'''VITAL_ITEMIDS = {
    "heart_rate": [211, 220045],
    "mean_bp": [456, 220052],
    "spo2": [646, 220277],
    "resp_rate": [618, 220210],
    "temperature": [223761, 678]
}'''
VITAL_ITEMIDS = {
    # Heart rate
    "heart_rate": [211, 220045],

    # Systolic BP
    "sbp": [51, 442, 455, 6701, 220179],

    # Diastolic BP
    "dbp": [8368, 8440, 8441, 8555, 220180],

    # Respiratory rate
    "resp_rate": [618, 220210],

    # Oxygen saturation
    "spo2": [646, 220277],

    # Temperature (Fahrenheit)
    "temperature": [223761, 678],

    # Glasgow Coma Scale (total)
    "gcs": [198, 226755],

    # FiO2 (fraction, NOT %)
    "fio2": [190, 223835],

    # O2 flow rate
    "o2_flow": [470, 471, 223834],
}
ALL_VITAL_ITEMIDS = sum(VITAL_ITEMIDS.values(), [])

def build_vitals(batch_icustays, icu_meta):
    chunks = pd.read_csv(
        f"{DATA_DIR}/CHARTEVENTS.csv",
        usecols=["SUBJECT_ID", "ICUSTAY_ID", "ITEMID", "CHARTTIME", "VALUENUM"],
        chunksize=5_000_000
    )

    out = []

    for df in chunks:
        df = df[df.ICUSTAY_ID.isin(batch_icustays)]
        df = df[df.ITEMID.isin(ALL_VITAL_ITEMIDS)]

        if df.empty:
            continue

        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        df = df.merge(
            icu_meta[["SUBJECT_ID", "ICUSTAY_ID", "INTIME"]],
            on=["SUBJECT_ID","ICUSTAY_ID"],
            how="left"
        )

        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        df = (
            df.groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin", "ITEMID"])["VALUENUM"]
            .mean()
            .reset_index()
        )

        out.append(df)

    df = pd.concat(out, ignore_index=True)

    # Pivot ITEMIDs → named columns
    features = {}
    for name, ids in VITAL_ITEMIDS.items():
        features[name] = (
            df[df.ITEMID.isin(ids)]
            .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["VALUENUM"]
            .mean()
        )

    vitals = pd.concat(features, axis=1).reset_index()
    return vitals

# %%
# 5 obtain desired lab features from labevents

'''LAB_ITEMIDS = {
    "anion gap": [50868],
    "albumin": [50862],
    "bilirubin": [50885],
    "creatinine": [50912],
    "glucose": [50931],
    "hemoglobin": [51222],
    "lactate": [50813],
    "platelet count": [51265],
    "potassium": [50971],
    "sodium": [50983],
    "wbc": [51516]
}'''
LAB_ITEMIDS = {
    # Hematology
    "wbc": [51301, 51516],
    "platelets": [51265],

    # Renal / liver
    "creatinine": [50912],
    "bilirubin": [50885],

    # Metabolic
    "lactate": [50813],

    # Coagulation
    "inr": [51237],

    # Blood gas / acid–base
    "ph": [50820],
    "pco2": [50818],
    "po2": [50821],
}

ALL_LAB_ITEMIDS = sum(LAB_ITEMIDS.values(), [])

def build_labs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned lab features from LABEVENTS.

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | lab_1 | lab_2 | ...
    """

    chunks = pd.read_csv(
        f"{DATA_DIR}/LABEVENTS.csv",
        usecols=[
            "SUBJECT_ID",
            "HADM_ID",
            "ITEMID",
            "CHARTTIME",
            "VALUENUM"
        ],
        chunksize=2_000_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch stays
        df = df[df.HADM_ID.isin(
            icu_meta[
                icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
            ].HADM_ID.unique()
        )]

        # 2. Filter to labs of interest
        df = df[df.ITEMID.isin(ALL_LAB_ITEMIDS)]

        if df.empty:
            continue

        # 3. Parse time
        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        # 4. Attach ICU INTIME
        df = df.merge(
            icu_meta[["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID", "INTIME"]],
            on=["SUBJECT_ID", "HADM_ID"],
            how="left"
        )

        # Drop labs outside ICU stay
        df = df[
            (df.CHARTTIME >= df.INTIME) &
            (df.CHARTTIME <= icu_meta.set_index("ICUSTAY_ID")
                              .loc[df.ICUSTAY_ID]
                              .OUTTIME.values)
        ]

        # 5. Compute 12h bin
        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        # 6. Aggregate within bin
        df = (
            df.groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin", "ITEMID"])["VALUENUM"]
            .mean()
            .reset_index()
        )

        out.append(df)

    if not out:
        return pd.DataFrame(columns=["SUBJECT_ID", "ICUSTAY_ID", "bin"])

    df = pd.concat(out, ignore_index=True)

    # 7. Pivot ITEMIDs → lab names
    lab_frames = []

    for lab, ids in LAB_ITEMIDS.items():
        tmp = (
            df[df.ITEMID.isin(ids)]
            .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["VALUENUM"]
            .mean()
            .rename(lab)
        )
        lab_frames.append(tmp)

    labs = pd.concat(lab_frames, axis=1).reset_index()

    return labs

# %%
# 6 obtain iv fluid sum and vasopressor sum  from inputevents

FLUID_ITEMIDS = [
    41913, 6190,  # NS
    30021, 2971, 44367, 225828,  # LR
    1848,  # D5W
    3066, 1521, 2358, 40548, 46564, 45403, 227456  # Albumin
]

VASOPRESSOR_ITEMIDS = [
    30120, 221906, 30047,  # norepinephrine
    221289, 30044, 30119,  # epinephrine
    221662, 5329, 30043,  # dopamine
    221749, 5656, 30128,  # phenylephrine
    22315, 1136, 1222 # vasopressin
]

def build_inputs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build action features (iv_fluids, vasopressors) binned into 12-hour windows.
    """

    # 1. Load INPUTEVENTS_MV
    df = pd.read_csv(
        f"{DATA_DIR}/INPUTEVENTS_MV.csv",
        usecols=[
            "SUBJECT_ID", 
            "ICUSTAY_ID",
            "ITEMID",
            "STARTTIME",
            "ENDTIME",
            "AMOUNT",
            "RATE"
        ]
    )

    df = df[df.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)]
    if df.empty:
        return pd.DataFrame(
            columns=["SUBJECT_ID", "ICUSTAY_ID", "bin", "iv_fluids", "vasopressors"]
        )

    df["STARTTIME"] = pd.to_datetime(df["STARTTIME"])
    df["ENDTIME"] = pd.to_datetime(df["ENDTIME"])

    # 2. Attach ICU INTIME
    df = df.merge(
        icu_meta[["SUBJECT_ID", "ICUSTAY_ID", "INTIME"]],
        on=["SUBJECT_ID", "ICUSTAY_ID"],
        how="left"
    )

    # 3. Build bins
    bins = []

    for _, row in icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
    ].iterrows():

        n_bins = int(
            np.ceil(
                (row.OUTTIME - row.INTIME).total_seconds()
                / (BIN_HOURS * 3600)
            )
        )

        for b in range(n_bins):
            bins.append({
                "SUBJECT_ID": row.SUBJECT_ID, 
                "ICUSTAY_ID": row.ICUSTAY_ID,
                "bin": b,
                "bin_start": row.INTIME + pd.Timedelta(hours=b * BIN_HOURS),
                "bin_end": row.INTIME + pd.Timedelta(hours=(b + 1) * BIN_HOURS),
            })

    bins_df = pd.DataFrame(bins)

    # 4. Helper: overlap minutes
    def overlap_minutes(start1, end1, start2, end2):
        start = max(start1, start2)
        end = min(end1, end2)
        return max(0, (end - start).total_seconds() / 60.0)

    # 5. IV FLUIDS (continuous sum)
    iv = df[df.ITEMID.isin(FLUID_ITEMIDS)].copy()
    iv = iv[(iv.STARTTIME.notna()) & (iv.ENDTIME.notna())]

    iv["duration_min"] = (
        iv.ENDTIME - iv.STARTTIME
    ).dt.total_seconds() / 60

    iv["RATE"] = iv["RATE"].fillna(
        iv["AMOUNT"] / iv["duration_min"]
    )

    iv = iv[(iv.RATE.notna()) & (iv.duration_min > 0)]

    iv_values = []

    for _, bin_row in bins_df.iterrows():
        active = iv[
            (iv.ICUSTAY_ID == bin_row.ICUSTAY_ID) &
            (iv.ENDTIME > bin_row.bin_start) &
            (iv.STARTTIME < bin_row.bin_end)
        ]

        total = 0.0
        for _, r in active.iterrows():
            mins = overlap_minutes(
                r.STARTTIME, r.ENDTIME,
                bin_row.bin_start, bin_row.bin_end
            )
            total += mins * r.RATE

        iv_values.append(total)

    bins_df["iv_fluids"] = iv_values

    # 6. VASOPRESSORS (continuous sum)
    vp = df[df.ITEMID.isin(VASOPRESSOR_ITEMIDS)].copy()
    vp = vp[(vp.STARTTIME.notna()) & (vp.ENDTIME.notna())]

    vp["duration_min"] = (
        vp.ENDTIME - vp.STARTTIME
    ).dt.total_seconds() / 60

    vp["RATE"] = vp["RATE"].fillna(
        vp["AMOUNT"] / vp["duration_min"]
    )

    vp = vp[(vp.RATE.notna()) & (vp.duration_min > 0)]

    vp_values = []

    for _, bin_row in bins_df.iterrows():
        active = vp[
            (vp.ICUSTAY_ID == bin_row.ICUSTAY_ID) &
            (vp.ENDTIME > bin_row.bin_start) &
            (vp.STARTTIME < bin_row.bin_end)
        ]

        total = 0.0
        for _, r in active.iterrows():
            mins = overlap_minutes(
                r.STARTTIME, r.ENDTIME,
                bin_row.bin_start, bin_row.bin_end
            )
            total += mins * r.RATE

        vp_values.append(total)

    bins_df["vasopressors"] = vp_values

    # 7. Final output
    return bins_df[[
        "SUBJECT_ID", 
        "ICUSTAY_ID",
        "bin",
        "iv_fluids",
        "vasopressors"
    ]]

# %%
# 7 Backtracked this for now, I don't think Alex actually ended up using OUTPUTEVENTS or INPUTEVENTS_CV

URINE_ITEMIDS = [
    40055,  # Urine Out Foley
    40069,  # Urine Out Void
    40094,  # Urine Out Condom Cath
    40428,  # Urine Out Straight Cath
    40715,  # Urine Out Suprapubic
    40473,  # Urine Out Ileoconduit
]

def build_outputs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned ICU output features (urine output).

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | urine_output
    """

    chunks = pd.read_csv(
        f"{DATA_DIR}/OUTPUTEVENTS.csv",
        usecols=[
            "ICUSTAY_ID",
            "ITEMID",
            "CHARTTIME",
            "VALUE"
        ],
        chunksize=1_000_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch ICU stays
        df = df[df.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)]
        if df.empty:
            continue

        # 2. Keep urine outputs only
        df = df[df.ITEMID.isin(URINE_ITEMIDS)]
        if df.empty:
            continue

        # 3. Parse time
        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        # 4. Attach ICU INTIME
        df = df.merge(
            icu_meta[["ICUSTAY_ID", "INTIME"]],
            on="ICUSTAY_ID",
            how="left"
        )

        # 5. Compute 12-hour bin
        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        # 6. Aggregate urine output
        urine = (
            df.groupby(["ICUSTAY_ID", "bin"])["VALUE"]
            .sum()
            .rename("urine_output")
        )

        out.append(urine)

    if not out:
        return pd.DataFrame(
            columns=["ICUSTAY_ID", "bin", "urine_output"]
        )

    outputs = pd.concat(out).reset_index()
    return outputs

# %%
# 8 obtain a binary of whether the patient has or hasnt received antibiotics by scanning to see if they
# received any of the common keywords for types of antibiotics

ANTIBIOTIC_KEYWORDS = [
    "cef", "ceph",
    "penicillin", "pip", "tazo",
    "vancomycin", "vanc",
    "levofloxacin", "ciprofloxacin",
    "meropenem", "imipenem",
    "azithromycin", "clarithromycin",
    "gentamicin", "amikacin",
    "clindamycin", "metronidazole",
    "doxycycline", "linezolid"
]

def build_prescriptions(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned prescription features (antibiotic exposure).

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | antibiotics
    """

    # Map ICU stays → admissions
    batch_meta = icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
    ][["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID", "INTIME", "OUTTIME"]]

    HADM_IDs = batch_meta.HADM_ID.unique()

    chunks = pd.read_csv(
        f"{DATA_DIR}/PRESCRIPTIONS.csv",
        usecols=[
            "SUBJECT_ID",
            "HADM_ID",
            "STARTDATE",
            "ENDDATE",
            "DRUG"
        ],
        chunksize=500_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch admissions
        df = df[df.HADM_ID.isin(HADM_IDs)]
        if df.empty:
            continue

        # 2. Identify antibiotics
        drug_lower = df["DRUG"].str.lower().fillna("")
        is_abx = drug_lower.apply(
            lambda x: any(k in x for k in ANTIBIOTIC_KEYWORDS)
        )
        df = df[is_abx]
        if df.empty:
            continue

        # 3. Parse times
        df["STARTDATE"] = pd.to_datetime(df["STARTDATE"])
        df["ENDDATE"] = pd.to_datetime(df["ENDDATE"])

        # If ENDDATE missing, assume one dose (common)
        df["ENDDATE"] = df["ENDDATE"].fillna(df["STARTDATE"])

        # 4. Attach ICU metadata
        df = df.merge(
            batch_meta,
            on=["SUBJECT_ID", "HADM_ID"],
            how="left"
        )

        # Drop prescriptions outside ICU stay
        df = df[
            (df.ENDDATE >= df.INTIME) &
            (df.STARTDATE <= df.OUTTIME)
        ]

        if df.empty:
            continue

        # 5. Expand prescription duration into bins
        rows = []

        for _, r in df.iterrows():
            start_bin = int(
                max(
                    0,
                    (r.STARTDATE - r.INTIME).total_seconds()
                    // (BIN_HOURS * 3600)
                )
            )
            end_bin = int(
                (r.ENDDATE - r.INTIME).total_seconds()
                // (BIN_HOURS * 3600)
            )

            for b in range(start_bin, end_bin + 1):
                rows.append({
                    "SUBJECT_ID": r.SUBJECT_ID,
                    "ICUSTAY_ID": r.ICUSTAY_ID,
                    "bin": b,
                    "antibiotics": 1
                })

        if rows:
            out.append(pd.DataFrame(rows))

    if not out:
        return pd.DataFrame(
            columns=["SUBJECT_ID", "ICUSTAY_ID", "bin", "antibiotics"]
        )

    # 6. Collapse duplicates
    prescriptions = (
        pd.concat(out, ignore_index=True)
        .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["antibiotics"]
        .max()
        .reset_index()
    )

    return prescriptions

# %%
# 9 perform batching and binning

icu_ids = np.sort(icu_meta.ICUSTAY_ID.unique())
batches = np.array_split(
    icu_ids,
    int(np.ceil(len(icu_ids) / BATCH_SIZE))
)

for i, batch_ids in enumerate(batches):
    print(f"Batch {i}: {len(batch_ids)} stays")

    batch_meta = icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ids)
    ]

    base = build_base_grid(batch_meta)
    vitals = build_vitals(batch_ids, icu_meta)
    labs = build_labs(batch_ids, icu_meta)
    inputs = build_inputs(batch_ids, icu_meta)
    #outputs = build_outputs(batch_ids, icu_meta)
    meds = build_prescriptions(batch_ids, icu_meta)

    df = base
    for feat in [vitals, labs, inputs, meds]:
        df = df.merge(
            feat,
            on=["SUBJECT_ID", "ICUSTAY_ID", "bin"],
            how="left"
        )

    df.to_parquet(
        f"{OUT_DIR}/batch_{i:02d}.parquet",
        index=False
    )
# Out:
# Batch 0: 2930 stays
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 17
#      12 batch_meta = icu_meta[
#      13     icu_meta.ICUSTAY_ID.isin(batch_ids)
#      14 ]
#      16 base = build_base_grid(batch_meta)
# ---> 17 vitals = build_vitals(batch_ids, icu_meta)
#      18 labs = build_labs(batch_ids, icu_meta)
#      19 inputs = build_inputs(batch_ids, icu_meta)
#
# Cell In[4], line 49, in build_vitals(batch_icustays, icu_meta)
#      41 chunks = pd.read_csv(
#      42     f"{DATA_DIR}/CHARTEVENTS.csv",
#      43     usecols=["SUBJECT_ID", "ICUSTAY_ID", "ITEMID", "CHARTTIME", "VALUENUM"],
#      44     chunksize=5_000_000
#      45 )
#      47 out = []
# ---> 49 for df in chunks:
#      50     df = df[df.ICUSTAY_ID.isin(batch_icustays)]
#      51     df = df[df.ITEMID.isin(ALL_VITAL_ITEMIDS)]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:1985, in TextFileReader.get_chunk(self, size)
#    1983         raise StopIteration
#    1984     size = min(size, self.nrows - self._currow)
# -> 1985 return self.read(nrows=size)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:850, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
# 10 batch merging

files = glob.glob(f"{OUT_DIR}/batch_*.parquet")

full_df = pd.concat(
    (pd.read_parquet(f) for f in files),
    ignore_index=True
)

# %%
# 11 data cleaning and imputation

phys_cols = list(VITAL_ITEMIDS.keys())

full_df = full_df.sort_values(["ICUSTAY_ID", "bin"])
full_df["antibiotics"] = full_df["antibiotics"].fillna(0)
full_df[phys_cols] = (
    full_df.groupby("ICUSTAY_ID")[phys_cols]
    .ffill()
)

intervention_cols = []  # e.g. vasopressors, antibiotics
full_df[intervention_cols] = full_df[intervention_cols].fillna(0)

numeric_cols = full_df.select_dtypes(include="number").columns

for c in numeric_cols:
    lo = full_df[c].quantile(0.001)
    hi = full_df[c].quantile(0.999)
    full_df[c] = full_df[c].clip(lo, hi)

full_df["heart_rate"] = full_df["heart_rate"].clip(30, 220)
full_df["spo2"] = full_df["spo2"].clip(50, 100)
full_df["sbp"] = full_df["sbp"].clip(50, 180)
full_df["dbp"] = full_df["dbp"].clip(30, 140)

# %%
# 12 iterative Bayesian-Ridge imputation for residual gaps

imputer = IterativeImputer(
    estimator=BayesianRidge(),
    max_iter=10,
    random_state=0
)


full_df[numeric_cols] = imputer.fit_transform(
    full_df[numeric_cols]
)

# %%
# 13 data audit to check validity (no Nan and no Inf), then save

assert full_df.isna().sum().sum() == 0
assert np.isfinite(full_df[numeric_cols]).all().all()

full_df.to_parquet(MERGED_PATH, index=False)

# %%
# 14 load from parquet file (only needs to be run if you don't want to run all the code before this point)

full_df = pd.read_parquet(MERGED_PATH)

# %%
# 15 group data into sequences by stay

def build_sequences(full_df, state_cols, action_cols, id_col="ICUSTAY_ID", time_col="bin", return_ids=True):

    sequences = []
    ids = []

    # Ensure proper ordering
    df = full_df.sort_values(["SUBJECT_ID", id_col, time_col])

    for (SUBJECT_ID, ICUSTAY_ID), group in df.groupby(["SUBJECT_ID", "ICUSTAY_ID"]):
        group = group.sort_values(time_col)

        states = group[state_cols].to_numpy(dtype=np.float32)
        actions = group[action_cols].to_numpy(dtype=np.float32)

        T = len(group)
        if T < 2:
            continue

        seq = {
            "SUBJECT_ID": SUBJECT_ID,
            "ICUSTAY_ID": ICUSTAY_ID,
            "states": states[:-1],       # (T-1, 18)
            "actions": actions[:-1],     # (T-1, 3)
            "next_states": states[1:],   # (T-1, 18)
            "length": T - 1
        }

        sequences.append(seq)
    return sequences
    
state_features = [
    "heart_rate", "sbp", "dbp", "resp_rate", "spo2", "temperature",
    "gcs", "fio2", "o2_flow", "wbc", "platelets", "creatinine",
    "bilirubin", "lactate", "inr", "ph", "pco2", "po2"
]
action_features = [
    "iv_fluids", "vasopressors", "antibiotics"
]
feature_cols = state_features + action_features

sequences = build_sequences(full_df, state_features, action_features)

# %%
# not using this data split anymore, as I think my second one is more robust
# still leaving it here just in case

def split_sequences_train_val_test(sequences, ids, seed=42):
    assert len(sequences) == len(ids)

    N = len(sequences)
    rng = np.random.default_rng(seed)

    indices = np.arange(N)
    rng.shuffle(indices)

    n_train = int(0.70 * N)
    n_val = int(0.15 * N)

    train_idx = indices[:n_train] # first 70%
    val_idx = indices[n_train:n_train + n_val] # the 15% from 70 to 85% range
    test_idx = indices[n_train + n_val:] # the 15% from 85 to 100% range

    def take(idx):
        return [sequences[i] for i in idx]

    X_train= take(train_idx)
    X_val= take(val_idx)
    X_test= take(test_idx)

    return X_train, X_val, X_test

#X_train, X_val, X_test = split_sequences_train_val_test(sequences)

# %%
# 16 data split
from collections import defaultdict

def split_sequences_by_subject(sequences, seed=42):
    # Collect unique subjects
    subject_to_seqs = defaultdict(list)

    for seq in sequences:
        subject_to_seqs[seq["SUBJECT_ID"]].append(seq)

    subjects = list(subject_to_seqs.keys())

    # Shuffle subjects
    rng = np.random.default_rng(seed)
    rng.shuffle(subjects)

    # Split subjects
    N = len(subjects)
    n_train = int(0.70 * N)
    n_val = int(0.15 * N)

    train_subjects = set(subjects[:n_train]) # first 70%
    val_subjects   = set(subjects[n_train:n_train + n_val]) # the 15% from 70 to 85% range
    test_subjects  = set(subjects[n_train + n_val:]) # the 15% from 85 to 100% range

    # Assign sequences
    train_seqs = []
    val_seqs = []
    test_seqs = []

    for subj, seqs in subject_to_seqs.items():
        if subj in train_subjects:
            train_seqs.extend(seqs)
        elif subj in val_subjects:
            val_seqs.extend(seqs)
        elif subj in test_subjects:
            test_seqs.extend(seqs)
        else:
            raise RuntimeError("Subject not assigned to any split")

    return train_seqs, val_seqs, test_seqs

train_seqs, val_seqs, test_seqs = split_sequences_by_subject(sequences)
print("done")
# Out:
# done

# %%
# 17 scaling data

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
all_train_states = np.concatenate([s["states"] for s in train_seqs], axis=0)
scaler.fit(all_train_states)

def apply_scaler(seqs, scaler):
    out = []
    for s in seqs:
        s2 = dict(s)
        s2["states"] = scaler.transform(s["states"])
        s2["next_states"] = scaler.transform(s["next_states"])
        out.append(s2)
    return out

train_seqs = apply_scaler(train_seqs, scaler)
val_seqs   = apply_scaler(val_seqs, scaler)
test_seqs  = apply_scaler(test_seqs, scaler)

# %%
def check_nan(split, name):
    for i, s in enumerate(split):
        if np.isnan(s["states"]).any():
            print(f"NaN in {name} states seq {i}")
        if np.isnan(s["actions"]).any():
            print(f"NaN in {name} actions seq {i}")
        if np.isnan(s["next_states"]).any():
            print(f"NaN in {name} next_states seq {i}")
        if np.isinf(s["states"]).any():
            print(f"NaN in {name} states seq {i}")
        if np.isinf(s["actions"]).any():
            print(f"NaN in {name} actions seq {i}")
        if np.isinf(s["next_states"]).any():
            print(f"NaN in {name} next_states seq {i}")

check_nan(train_seqs, "train")
check_nan(val_seqs, "val")
check_nan(test_seqs, "test")
assert not np.isnan(all_train_states).any()
assert not np.isinf(all_train_states).any()

# %%
# 18

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

class ICUDataset(Dataset):
    def __init__(self, sequences):
        self.seqs = sequences

    def __len__(self):
        return len(self.seqs)

    def __getitem__(self, idx):
        s = self.seqs[idx]
        return {
            "states": torch.tensor(s["states"], dtype=torch.float32),
            "actions": torch.tensor(s["actions"], dtype=torch.float32),
            "next_states": torch.tensor(s["next_states"], dtype=torch.float32),
            "length": s["length"]
        }


def collate_fn(batch):
    lengths = torch.tensor([b["length"] for b in batch], dtype=torch.long)
    max_len = lengths.max()

    def pad(x):
        out = torch.zeros(len(batch), max_len, x[0].shape[-1])
        for i, b in enumerate(x):
            out[i, :b.shape[0]] = b
        return out

    states = pad([b["states"] for b in batch])
    actions = pad([b["actions"] for b in batch])
    next_states = pad([b["next_states"] for b in batch])

    mask = torch.arange(max_len)[None, :] < lengths[:, None]

    return states, actions, next_states, mask

# %%
# XGboost model setup

from sklearn.model_selection import train_test_split

def filter_rows_by_icu_ids(full_df, icu_ids):
    return full_df[full_df["ICUSTAY_ID"].isin(icu_ids)]


def build_xgb_rows_from_full_df(full_df, feature_cols, action_cols, id_col="ICUSTAY_ID"):
    """
    Converts time-series ICU data into (X, y) pairs:
        X = [state_t, action_t]
        y = state_{t+1}
    """
    X_list, y_list = [], []

    for icu_id, g in full_df.groupby(id_col):
        g = g.sort_values("bin")

        s = g[feature_cols].values
        a = g[action_cols].values

        # t -> t+1 transition
        X = np.concatenate([s[:-1], a[:-1]], axis=1)
        y = s[1:]

        X_list.append(X)
        y_list.append(y)

    X = np.vstack(X_list)
    y = np.vstack(y_list)

    return X, y

def make_subject_splits(full_df,
                        subject_col="SUBJECT_ID",
                        train_frac=0.7, val_frac=0.15, test_frac=0.15,
                        random_state=42):

    unique_subjects = full_df[subject_col].unique()

    train_subj, temp_subj = train_test_split(
        unique_subjects,
        test_size=(1 - train_frac),
        random_state=random_state,
        shuffle=True,
        
    )

    val_size_adjusted = test_frac / (val_frac + test_frac)

    val_subj, test_subj = train_test_split(
        temp_subj,
        test_size=val_size_adjusted,
        random_state=random_state,
        shuffle=True
    )

    return train_subj, val_subj, test_subj

def subjects_to_icu_ids(full_df, subject_ids):
    return full_df[full_df["SUBJECT_ID"].isin(subject_ids)]["ICUSTAY_ID"].unique()


from xgboost import XGBRegressor

def train_xgb(X_train, y_train, X_val, y_val):
    model = XGBRegressor(
        n_estimators=800,
        max_depth=8,
        learning_rate=0.03,
        subsample=0.8,
        colsample_bytree=0.8,
        tree_method="hist",
        objective="reg:squarederror",
        n_jobs=-1,
        verbosity=1,
    )

    model.fit(
        X_train,
        y_train,
        eval_set=[(X_val, y_val)],
        verbose=True,
    )

    return model

def xgb_rollout_rmse(model, full_df, feature_cols, action_cols, icu_ids):
    rmses = []

    for icu_id in icu_ids:
        g = full_df[full_df["ICUSTAY_ID"] == icu_id].sort_values("bin")

        s = g[feature_cols].values
        a = g[action_cols].values

        cur = s[0].copy()
        errs = []

        for t in range(len(s) - 1):
            x = np.concatenate([cur, a[t]])[None, :]
            pred = model.predict(x)[0]

            true = s[t + 1]
            errs.append((pred - true) ** 2)

            cur = pred  # rollout!

        rmse = np.sqrt(np.mean(errs))
        rmses.append(rmse)

    return np.mean(rmses)

# %%
# GRU model setup

class GRUModel(nn.Module):
    def __init__(self, state_dim=18, action_dim=3, hidden=128, layers=2):
        super(GRUModel, self).__init__()
        self.gru = nn.GRU(state_dim + action_dim, hidden, layers, batch_first=True)
        self.out = nn.Linear(hidden, state_dim)

    def forward(self, s, a):
        x = torch.cat([s, a], dim=-1)
        out, _ = self.gru(x)
        return self.out(out)

# %%
# 19 LSTM model setup

class LSTMModel(nn.Module):
    def __init__(self, state_dim=18, action_dim=3, hidden=128, layers=2):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(state_dim + action_dim, hidden, layers, batch_first=True)
        self.out = nn.Linear(hidden, state_dim)

    def forward(self, s, a):
        x = torch.cat([s, a], dim=-1)
        out, _ = self.lstm(x)
        return self.out(out)

# %%
# 20 CFC model setup
import torch.nn.functional as F

class CfCCell(nn.Module):
    """
    Closed-form Continuous-time (CfC) Neural Network Cell
    
    Implements a liquid time-constant network with closed-form solutions
    to the underlying ODEs for efficient computation.
    """
    
    def __init__(self, input_size, hidden_size):
        super(CfCCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        
        # Learnable parameters for the ODE dynamics
        self.ff1 = nn.Linear(input_size + hidden_size, hidden_size)
        self.ff2 = nn.Linear(input_size + hidden_size, hidden_size)
        self.time_a = nn.Linear(input_size + hidden_size, hidden_size)
        self.time_b = nn.Linear(input_size + hidden_size, hidden_size)
        
    def forward(self, x, h, dt=1.0):
        """
        Forward pass through the CfC cell
        
        Args:
            x: Input tensor of shape (batch_size, input_size)
            h: Hidden state tensor of shape (batch_size, hidden_size)
            dt: Time step (default=1.0)
            
        Returns:
            new_h: Updated hidden state
        """
        # Concatenate input and hidden state
        combined = torch.cat([x, h], dim=1)
        
        # Compute the ODE parameters
        # f(x,h) represents the target value the state wants to reach
        f = torch.tanh(self.ff1(combined))
        
        # Time constant (how fast the state changes)
        # Using softplus to ensure positivity
        tau = F.softplus(self.time_a(combined)) + 0.1  # Add small constant for stability
        
        # Input modulation
        input_gate = torch.sigmoid(self.time_b(combined))
        
        # Closed-form solution to the ODE: dh/dt = (f - h) / tau
        # Solution: h(t+dt) = f + (h(t) - f) * exp(-dt/tau)
        decay = torch.exp(-dt / tau)
        new_h = f + (h - f) * decay
        
        # Apply input modulation
        new_h = input_gate * new_h + (1 - input_gate) * h
        
        return new_h


class CfCNetwork(nn.Module):
    """
    Complete CfC Neural Network for sequence processing
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2):
        super(CfCNetwork, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        # Stack of CfC cells
        self.cells = nn.ModuleList()
        for i in range(num_layers):
            cell_input_size = input_size if i == 0 else hidden_size
            self.cells.append(CfCCell(cell_input_size, hidden_size))
        
        # Output layer
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden=None, dt=1.0):
        """
        Forward pass through the network
        
        Args:
            x: Input tensor of shape (batch_size, seq_len, input_size)
            hidden: Initial hidden states (optional)
            dt: Time step
            
        Returns:
            outputs: Output tensor of shape (batch_size, seq_len, output_size)
            hidden: Final hidden states
        """
        batch_size, seq_len, _ = x.size()
        
        # Initialize hidden states if not provided
        if hidden is None:
            hidden = [torch.zeros(batch_size, self.hidden_size, device=x.device) 
                     for _ in range(self.num_layers)]
        
        outputs = []
        
        # Process sequence
        for t in range(seq_len):
            layer_input = x[:, t, :]
            
            # Pass through each layer
            for i, cell in enumerate(self.cells):
                hidden[i] = cell(layer_input, hidden[i], dt)
                layer_input = hidden[i]
            
            # Generate output
            output = self.fc_out(hidden[-1])
            outputs.append(output)
        
        # Stack outputs
        outputs = torch.stack(outputs, dim=1)
        
        return outputs

# %%
# 21

def masked_mse(pred, target, mask):
    mask = mask.unsqueeze(-1)
    if mask.sum() == 0:
        print("Oh no")
    return ((pred - target) ** 2 * mask).sum() / mask.sum()

# %%
# 22 define our own train model function so we can control for training differences between models

from torch.cuda.amp import autocast, GradScaler

def train_model(model, train_loader, val_loader, best_save, epochs=30, lr=1e-3, device="cuda"):
    model.to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    scaler = GradScaler()

    best_val = float("inf")
    model.double()
    for epoch in range(epochs):
        model.train()

        for s, a, ns, mask in train_loader:
            s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)
            s = s.double()
            a = a.double()

            with autocast():
                if best_save == "best_gru.pt" or best_save == "best_lstm.pt":
                    pred = model(s, a)
                else:
                    x = torch.cat([s, a], dim=-1)
                    pred = model(x)
                loss = masked_mse(pred, ns, mask)

            opt.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(opt)
            scaler.update()

        # Validation
        model.eval()
        model.double()
        with torch.no_grad():
            vals = []
            for s, a, ns, mask in val_loader:
                s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)
                s = s.double()
                a = a.double()
                if best_save == "best_gru.pt" or best_save == "best_lstm.pt":
                    pred = model(s, a)
                else:
                    x = torch.cat([s, a], dim=-1)
                    pred = model(x)
                vals.append(masked_mse(pred, ns, mask).item())

            val_loss = np.mean(vals)

        print(f"Epoch {epoch}: val loss={val_loss:.5f}")

        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), best_save)

# %%
# 23

def rollout_rmse(model, loader, K, model_type, device="cuda"):
    model.eval()
    rmses = []

    with torch.no_grad():
        for s, a, ns, mask in loader:
            s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)
            s = s.double()
            a = a.double()
            cur = s.clone()
            cur = cur.to(device)
            cur = cur.double()

            for k in range(K):
                if model_type == "gru" or model_type == "lstm":
                    pred = model(cur, a)
                else:
                    x = torch.cat([cur, a], dim=-1)
                    pred = model(x)
                cur = pred  # teacher forcing OFF

            err = (cur - ns) ** 2
            mask_f = mask.unsqueeze(-1)
            err = err * mask_f

            rmse = torch.sqrt(err.sum() / (mask_f.sum() * err.shape[-1]))
            rmses.append(rmse.item())

    return np.mean(rmses)

# %%
# 24 function to load everything up and train a model

def run_experiment(train_seqs, val_seqs, test_seqs, model_type="gru"):
    train_ds = ICUDataset(train_seqs)
    val_ds = ICUDataset(val_seqs)
    test_ds = ICUDataset(test_seqs)

    train_loader = DataLoader(train_ds, batch_size=64, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_ds, batch_size=64, collate_fn=collate_fn)
    test_loader = DataLoader(test_ds, batch_size=64, collate_fn=collate_fn)

    if model_type == "gru":
        model = GRUModel()
        best_save = "best_gru.pt"
    elif model_type == "cfc":
        model = CfCNetwork()
        best_save = "best_cfc.pt"
    else:
        model = LSTMModel()
        best_save = "best_lstm.pt"
    
    #comment out the below line before running if you wish ti simpkly load the model and test it, rather than train it
    train_model(model, train_loader, val_loader, best_save)

    model.load_state_dict(torch.load(best_save))
    model.to("cuda")
    model.double()

    print("1-step RMSE:", rollout_rmse(model, test_loader, 1, model_type))
    print("3-step RMSE:", rollout_rmse(model, test_loader, 3, model_type))
    print("5-step RMSE:", rollout_rmse(model, test_loader, 5, model_type))

# %%
# 25 call experiment on GRU

print("Training GRU")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="gru")
#noting here a train time of 19m 18.8s
# Out:
# Training GRU
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\1556699811.py:8: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\1556699811.py:20: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 0: val loss=0.05227
# Epoch 1: val loss=0.05073
# Epoch 2: val loss=0.04144
# Epoch 3: val loss=0.03884
# Epoch 4: val loss=0.04074
# Epoch 5: val loss=0.03775
# Epoch 6: val loss=0.03827
# Epoch 7: val loss=0.04062
# Epoch 8: val loss=0.03810
# Epoch 9: val loss=0.03641
# Epoch 10: val loss=0.03558
# Epoch 11: val loss=0.03568
# Epoch 12: val loss=0.04010
# Epoch 13: val loss=0.03588
# Epoch 14: val loss=0.03739
# Epoch 15: val loss=0.03709
# Epoch 16: val loss=0.04152
# Epoch 17: val loss=0.03537
# Epoch 18: val loss=0.03500
# Epoch 19: val loss=0.03582
# Epoch 20: val loss=0.03584
# Epoch 21: val loss=0.03472
# Epoch 22: val loss=0.03567
# Epoch 23: val loss=0.03663
# Epoch 24: val loss=0.03491
# Epoch 25: val loss=0.03465
# Epoch 26: val loss=0.03496
# Epoch 27: val loss=0.03491
# Epoch 28: val loss=0.03466
# Epoch 29: val loss=0.03690
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\2780229667.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_save))
# 1-step RMSE: 0.04256316582922921
# 3-step RMSE: 0.04782032710702248
# 5-step RMSE: 0.05313556682288646

# %%
# 25 call experiment on CfC

print("Training CFC")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc")
# noting here a 134 min 38.9 sec train time
# Out:
# Training CFC
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\1556699811.py:8: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\1556699811.py:20: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 0: val loss=0.05668
# Epoch 1: val loss=0.04460
# Epoch 2: val loss=0.04253
# Epoch 3: val loss=0.04185
# Epoch 4: val loss=0.03910
# Epoch 5: val loss=0.03805
# Epoch 6: val loss=0.04139
# Epoch 7: val loss=0.03772
# Epoch 8: val loss=0.03867
# Epoch 9: val loss=0.03791
# Epoch 10: val loss=0.03544
# Epoch 11: val loss=0.03592
# Epoch 12: val loss=0.03808
# Epoch 13: val loss=0.03631
# Epoch 14: val loss=0.03666
# Epoch 15: val loss=0.03583
# Epoch 16: val loss=0.03698
# Epoch 17: val loss=0.03616
# Epoch 18: val loss=0.03553
# Epoch 19: val loss=0.03558
# Epoch 20: val loss=0.03554
# Epoch 21: val loss=0.03488
# Epoch 22: val loss=0.03671
# Epoch 23: val loss=0.03618
# Epoch 24: val loss=0.03506
# Epoch 25: val loss=0.03468
# Epoch 26: val loss=0.03543
# Epoch 27: val loss=0.03580
# Epoch 28: val loss=0.03568
# Epoch 29: val loss=0.03443
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\2780229667.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_save))
# 1-step RMSE: 0.04243338242172522
# 3-step RMSE: 0.04760321348940961
# 5-step RMSE: 0.05265821333063225

# %%
# call experiment on LSTM

print("Training LSTM")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="lstm")
#noting an execution time of 23m 44.7s
# Out:
# Training LSTM
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\1556699811.py:8: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\1556699811.py:20: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 0: val loss=0.06292
# Epoch 1: val loss=0.04860
# Epoch 2: val loss=0.04425
# Epoch 3: val loss=0.04429
# Epoch 4: val loss=0.04053
# Epoch 5: val loss=0.03781
# Epoch 6: val loss=0.03794
# Epoch 7: val loss=0.03727
# Epoch 8: val loss=0.03626
# Epoch 9: val loss=0.03723
# Epoch 10: val loss=0.03662
# Epoch 11: val loss=0.03588
# Epoch 12: val loss=0.03537
# Epoch 13: val loss=0.03483
# Epoch 14: val loss=0.03603
# Epoch 15: val loss=0.03483
# Epoch 16: val loss=0.03526
# Epoch 17: val loss=0.03535
# Epoch 18: val loss=0.03512
# Epoch 19: val loss=0.04651
# Epoch 20: val loss=0.03422
# Epoch 21: val loss=0.03425
# Epoch 22: val loss=0.03586
# Epoch 23: val loss=0.03495
# Epoch 24: val loss=0.03488
# Epoch 25: val loss=0.03441
# Epoch 26: val loss=0.03425
# Epoch 27: val loss=0.03418
# Epoch 28: val loss=0.03398
# Epoch 29: val loss=0.03375
# C:\Users\david\AppData\Local\Temp\ipykernel_10956\2780229667.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_save))
# 1-step RMSE: 0.04221205327347199
# 3-step RMSE: 0.04744296850874657
# 5-step RMSE: 0.052441882458618215

# %%
# XGB experimental run

train_subj, val_subj, test_subj = make_subject_splits(full_df)

train_icu_ids = subjects_to_icu_ids(full_df, train_subj)
val_icu_ids   = subjects_to_icu_ids(full_df, val_subj)
test_icu_ids  = subjects_to_icu_ids(full_df, test_subj)

train_df = filter_rows_by_icu_ids(full_df, train_icu_ids)
val_df   = filter_rows_by_icu_ids(full_df, val_icu_ids)
test_df  = filter_rows_by_icu_ids(full_df, test_icu_ids)

X_train, y_train = build_xgb_rows_from_full_df(train_df, state_features, action_features)
X_val, y_val     = build_xgb_rows_from_full_df(val_df, state_features, action_features)

# Train
xgb_model = train_xgb(X_train, y_train, X_val, y_val)

# Evaluate with rollout
test_rmse = xgb_rollout_rmse(
    xgb_model, full_df, state_features, action_features, test_icu_ids
)

print("XGBoost Rollout RMSE:", test_rmse)
# Out:
# [0]	validation_0-rmse:28.45395
# [1]	validation_0-rmse:28.09233
# [2]	validation_0-rmse:27.74554
# [3]	validation_0-rmse:27.45982
# [4]	validation_0-rmse:27.13980
# [5]	validation_0-rmse:26.84406
# [6]	validation_0-rmse:26.55457
