# %%
# 1 Library setup
import os
import glob
import numpy as np
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import train_test_split
from collections import defaultdict
from sklearn.preprocessing import MinMaxScaler
from torch.amp import GradScaler
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

DATA_DIR = "data/data"
OUT_DIR = "icu_batches_fixed"
MERGED_PATH = "icu_merged_fixed.parquet"

BIN_HOURS = 12
BATCH_SIZE = 3000

os.makedirs(OUT_DIR, exist_ok=True)

# %%
# 2 Load data and setup metadata

icustays = pd.read_csv(f"{DATA_DIR}/ICUSTAYS.csv")
admissions = pd.read_csv(f"{DATA_DIR}/ADMISSIONS.csv")
patients = pd.read_csv(f"{DATA_DIR}/PATIENTS.csv")

icu_meta = (
    icustays
    .merge(admissions, on=["SUBJECT_ID", "HADM_ID"], how="left")
    .merge(patients, on="SUBJECT_ID", how="left")
)

icu_meta = icu_meta[[
    "SUBJECT_ID",
    "HADM_ID",
    "ICUSTAY_ID",
    "INTIME",
    "OUTTIME"
]]

icu_meta["INTIME"] = pd.to_datetime(icu_meta["INTIME"])
icu_meta["OUTTIME"] = pd.to_datetime(icu_meta["OUTTIME"])


# I am no longer calling this, as we are running into the issue of somehow the icustay_ids with missing 
# out times are also missing from our computed out time results, but the code may prove useful later
def compute_last_event_time():
    last_times = []

    # CHARTEVENTS
    ce = pd.read_csv(
        f"{DATA_DIR}/CHARTEVENTS.csv",
        usecols=["ICUSTAY_ID", "CHARTTIME"]
    )
    ce["CHARTTIME"] = pd.to_datetime(ce["CHARTTIME"])
    last_times.append(
        ce.groupby("ICUSTAY_ID")["CHARTTIME"].max()
    )

    # INPUTEVENTS_MV
    ie = pd.read_csv(
        f"{DATA_DIR}/INPUTEVENTS_MV.csv",
        usecols=["ICUSTAY_ID", "ENDTIME"]
    )
    ie["ENDTIME"] = pd.to_datetime(ie["ENDTIME"])
    last_times.append(
        ie.groupby("ICUSTAY_ID")["ENDTIME"].max()
    )

    # OUTPUTEVENTS
    oe = pd.read_csv(
        f"{DATA_DIR}/OUTPUTEVENTS.csv",
        usecols=["ICUSTAY_ID", "CHARTTIME"]
    )
    oe["CHARTTIME"] = pd.to_datetime(oe["CHARTTIME"])
    last_times.append(
        oe.groupby("ICUSTAY_ID")["CHARTTIME"].max()
    )

    # PRESCRIPTIONS
    pr = pd.read_csv(
        f"{DATA_DIR}/PRESCRIPTIONS.csv",
        usecols=["ICUSTAY_ID", "ENDDATE"]
    )
    pr["ENDDATE"] = pd.to_datetime(pr["ENDDATE"])
    last_times.append(
        pr.groupby("ICUSTAY_ID")["ENDDATE"].max()
    )

    # Combine all
    all_last = pd.concat(last_times, axis=1)
    return all_last.max(axis=1)  # row-wise max


print("Missing outtime:", icu_meta["OUTTIME"].isna().sum())
icu_meta = icu_meta.dropna(subset=["OUTTIME"]).reset_index(drop=True)
assert icu_meta["OUTTIME"].notna().all()
assert (icu_meta["OUTTIME"] > icu_meta["INTIME"]).all()
# Out:
# Missing outtime: 10

# %%
# 3 create structure for bins

def build_base_grid(batch_meta):
    rows = []
    for _, r in batch_meta.iterrows():
        n_bins = int(
            np.ceil(
                (r.OUTTIME - r.INTIME).total_seconds()
                / (BIN_HOURS * 3600)
            )
        )
        for b in range(n_bins):
            rows.append({
                "SUBJECT_ID": r.SUBJECT_ID,
                "ICUSTAY_ID": r.ICUSTAY_ID,
                "bin": b
            })
    return pd.DataFrame(rows)

# %%
# 4 obtain desired vitals info from chartevents

'''VITAL_ITEMIDS = {
    "heart_rate": [211, 220045],
    "mean_bp": [456, 220052],
    "spo2": [646, 220277],
    "resp_rate": [618, 220210],
    "temperature": [223761, 678]
}'''
VITAL_ITEMIDS = {
    # Heart rate
    "heart_rate": [211, 220045],

    # Systolic BP
    "sbp": [51, 442, 455, 6701, 220179],

    # Diastolic BP
    "dbp": [8368, 8440, 8441, 8555, 220180],

    # Respiratory rate
    "resp_rate": [618, 220210],

    # Oxygen saturation
    "spo2": [646, 220277],

    # Temperature (Fahrenheit)
    "temperature": [223761, 678],

    # Glasgow Coma Scale (total)
    "gcs": [198, 226755],

    # FiO2 (fraction, NOT %)
    "fio2": [190, 223835],

    # O2 flow rate
    "o2_flow": [470, 471, 223834],
}
ALL_VITAL_ITEMIDS = sum(VITAL_ITEMIDS.values(), [])

def build_vitals(batch_icustays, icu_meta):
    chunks = pd.read_csv(
        f"{DATA_DIR}/CHARTEVENTS.csv",
        usecols=["SUBJECT_ID", "ICUSTAY_ID", "ITEMID", "CHARTTIME", "VALUENUM"],
        chunksize=5_000_000
    )

    out = []

    for df in chunks:
        df = df[df.ICUSTAY_ID.isin(batch_icustays)]
        df = df[df.ITEMID.isin(ALL_VITAL_ITEMIDS)]

        if df.empty:
            continue

        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        df = df.merge(
            icu_meta[["SUBJECT_ID", "ICUSTAY_ID", "INTIME"]],
            on=["SUBJECT_ID","ICUSTAY_ID"],
            how="left"
        )

        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        df = (
            df.groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin", "ITEMID"])["VALUENUM"]
            .mean()
            .reset_index()
        )

        out.append(df)

    df = pd.concat(out, ignore_index=True)

    # Pivot ITEMIDs → named columns
    features = {}
    for name, ids in VITAL_ITEMIDS.items():
        features[name] = (
            df[df.ITEMID.isin(ids)]
            .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["VALUENUM"]
            .mean()
        )

    vitals = pd.concat(features, axis=1).reset_index()
    return vitals

# %%
# 5 obtain desired lab features from labevents

'''LAB_ITEMIDS = {
    "anion gap": [50868],
    "albumin": [50862],
    "bilirubin": [50885],
    "creatinine": [50912],
    "glucose": [50931],
    "hemoglobin": [51222],
    "lactate": [50813],
    "platelet count": [51265],
    "potassium": [50971],
    "sodium": [50983],
    "wbc": [51516]
}'''
LAB_ITEMIDS = {
    # Hematology
    "wbc": [51301, 51516],
    "platelets": [51265],

    # Renal / liver
    "creatinine": [50912],
    "bilirubin": [50885],

    # Metabolic
    "lactate": [50813],

    # Coagulation
    "inr": [51237],

    # Blood gas / acid–base
    "ph": [50820],
    "pco2": [50818],
    "po2": [50821],
}

ALL_LAB_ITEMIDS = sum(LAB_ITEMIDS.values(), [])

def build_labs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned lab features from LABEVENTS.

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | lab_1 | lab_2 | ...
    """

    chunks = pd.read_csv(
        f"{DATA_DIR}/LABEVENTS.csv",
        usecols=[
            "SUBJECT_ID",
            "HADM_ID",
            "ITEMID",
            "CHARTTIME",
            "VALUENUM"
        ],
        chunksize=2_000_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch stays
        df = df[df.HADM_ID.isin(
            icu_meta[
                icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
            ].HADM_ID.unique()
        )]

        # 2. Filter to labs of interest
        df = df[df.ITEMID.isin(ALL_LAB_ITEMIDS)]

        if df.empty:
            continue

        # 3. Parse time
        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        # 4. Attach ICU INTIME
        df = df.merge(
            icu_meta[["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID", "INTIME"]],
            on=["SUBJECT_ID", "HADM_ID"],
            how="left"
        )

        # Drop labs outside ICU stay
        df = df[
            (df.CHARTTIME >= df.INTIME) &
            (df.CHARTTIME <= icu_meta.set_index("ICUSTAY_ID")
                              .loc[df.ICUSTAY_ID]
                              .OUTTIME.values)
        ]

        # 5. Compute 12h bin
        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        # 6. Aggregate within bin
        df = (
            df.groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin", "ITEMID"])["VALUENUM"]
            .mean()
            .reset_index()
        )

        out.append(df)

    if not out:
        return pd.DataFrame(columns=["SUBJECT_ID", "ICUSTAY_ID", "bin"])

    df = pd.concat(out, ignore_index=True)

    # 7. Pivot ITEMIDs → lab names
    lab_frames = []

    for lab, ids in LAB_ITEMIDS.items():
        tmp = (
            df[df.ITEMID.isin(ids)]
            .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["VALUENUM"]
            .mean()
            .rename(lab)
        )
        lab_frames.append(tmp)

    labs = pd.concat(lab_frames, axis=1).reset_index()

    return labs

# %%
# 6 obtain iv fluid sum and vasopressor sum  from inputevents

FLUID_ITEMIDS = [
    41913, 6190,  # NS
    30021, 2971, 44367, 225828,  # LR
    1848,  # D5W
    3066, 1521, 2358, 40548, 46564, 45403, 227456  # Albumin
]

VASOPRESSOR_ITEMIDS = [
    30120, 221906, 30047,  # norepinephrine
    221289, 30044, 30119,  # epinephrine
    221662, 5329, 30043,  # dopamine
    221749, 5656, 30128,  # phenylephrine
    22315, 1136, 1222 # vasopressin
]

def build_inputs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build action features (iv_fluids, vasopressors) binned into 12-hour windows.
    """

    # 1. Load INPUTEVENTS_MV
    df = pd.read_csv(
        f"{DATA_DIR}/INPUTEVENTS_MV.csv",
        usecols=[
            "SUBJECT_ID", 
            "ICUSTAY_ID",
            "ITEMID",
            "STARTTIME",
            "ENDTIME",
            "AMOUNT",
            "RATE"
        ]
    )

    df = df[df.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)]
    if df.empty:
        return pd.DataFrame(
            columns=["SUBJECT_ID", "ICUSTAY_ID", "bin", "iv_fluids", "vasopressors"]
        )

    df["STARTTIME"] = pd.to_datetime(df["STARTTIME"])
    df["ENDTIME"] = pd.to_datetime(df["ENDTIME"])

    # 2. Attach ICU INTIME
    df = df.merge(
        icu_meta[["SUBJECT_ID", "ICUSTAY_ID", "INTIME"]],
        on=["SUBJECT_ID", "ICUSTAY_ID"],
        how="left"
    )

    # 3. Build bins
    bins = []

    for _, row in icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
    ].iterrows():

        n_bins = int(
            np.ceil(
                (row.OUTTIME - row.INTIME).total_seconds()
                / (BIN_HOURS * 3600)
            )
        )

        for b in range(n_bins):
            bins.append({
                "SUBJECT_ID": row.SUBJECT_ID, 
                "ICUSTAY_ID": row.ICUSTAY_ID,
                "bin": b,
                "bin_start": row.INTIME + pd.Timedelta(hours=b * BIN_HOURS),
                "bin_end": row.INTIME + pd.Timedelta(hours=(b + 1) * BIN_HOURS),
            })

    bins_df = pd.DataFrame(bins)

    # 4. Helper: overlap minutes
    def overlap_minutes(start1, end1, start2, end2):
        start = max(start1, start2)
        end = min(end1, end2)
        return max(0, (end - start).total_seconds() / 60.0)

    # 5. IV FLUIDS (continuous sum)
    iv = df[df.ITEMID.isin(FLUID_ITEMIDS)].copy()
    iv = iv[(iv.STARTTIME.notna()) & (iv.ENDTIME.notna())]

    iv["duration_min"] = (
        iv.ENDTIME - iv.STARTTIME
    ).dt.total_seconds() / 60

    iv["RATE"] = iv["RATE"].fillna(
        iv["AMOUNT"] / iv["duration_min"]
    )

    iv = iv[(iv.RATE.notna()) & (iv.duration_min > 0)]

    iv_values = []

    for _, bin_row in bins_df.iterrows():
        active = iv[
            (iv.ICUSTAY_ID == bin_row.ICUSTAY_ID) &
            (iv.ENDTIME > bin_row.bin_start) &
            (iv.STARTTIME < bin_row.bin_end)
        ]

        total = 0.0
        for _, r in active.iterrows():
            mins = overlap_minutes(
                r.STARTTIME, r.ENDTIME,
                bin_row.bin_start, bin_row.bin_end
            )
            total += mins * r.RATE

        iv_values.append(total)

    bins_df["iv_fluids"] = iv_values

    # 6. VASOPRESSORS (continuous sum)
    vp = df[df.ITEMID.isin(VASOPRESSOR_ITEMIDS)].copy()
    vp = vp[(vp.STARTTIME.notna()) & (vp.ENDTIME.notna())]

    vp["duration_min"] = (
        vp.ENDTIME - vp.STARTTIME
    ).dt.total_seconds() / 60

    vp["RATE"] = vp["RATE"].fillna(
        vp["AMOUNT"] / vp["duration_min"]
    )

    vp = vp[(vp.RATE.notna()) & (vp.duration_min > 0)]

    vp_values = []

    for _, bin_row in bins_df.iterrows():
        active = vp[
            (vp.ICUSTAY_ID == bin_row.ICUSTAY_ID) &
            (vp.ENDTIME > bin_row.bin_start) &
            (vp.STARTTIME < bin_row.bin_end)
        ]

        total = 0.0
        for _, r in active.iterrows():
            mins = overlap_minutes(
                r.STARTTIME, r.ENDTIME,
                bin_row.bin_start, bin_row.bin_end
            )
            total += mins * r.RATE

        vp_values.append(total)

    bins_df["vasopressors"] = vp_values

    # 7. Final output
    return bins_df[[
        "SUBJECT_ID", 
        "ICUSTAY_ID",
        "bin",
        "iv_fluids",
        "vasopressors"
    ]]

# %%
# 7 Backtracked this for now, I don't think Alex actually ended up using OUTPUTEVENTS or INPUTEVENTS_CV

URINE_ITEMIDS = [
    40055,  # Urine Out Foley
    40069,  # Urine Out Void
    40094,  # Urine Out Condom Cath
    40428,  # Urine Out Straight Cath
    40715,  # Urine Out Suprapubic
    40473,  # Urine Out Ileoconduit
]

def build_outputs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned ICU output features (urine output).

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | urine_output
    """

    chunks = pd.read_csv(
        f"{DATA_DIR}/OUTPUTEVENTS.csv",
        usecols=[
            "ICUSTAY_ID",
            "ITEMID",
            "CHARTTIME",
            "VALUE"
        ],
        chunksize=1_000_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch ICU stays
        df = df[df.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)]
        if df.empty:
            continue

        # 2. Keep urine outputs only
        df = df[df.ITEMID.isin(URINE_ITEMIDS)]
        if df.empty:
            continue

        # 3. Parse time
        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        # 4. Attach ICU INTIME
        df = df.merge(
            icu_meta[["ICUSTAY_ID", "INTIME"]],
            on="ICUSTAY_ID",
            how="left"
        )

        # 5. Compute 12-hour bin
        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        # 6. Aggregate urine output
        urine = (
            df.groupby(["ICUSTAY_ID", "bin"])["VALUE"]
            .sum()
            .rename("urine_output")
        )

        out.append(urine)

    if not out:
        return pd.DataFrame(
            columns=["ICUSTAY_ID", "bin", "urine_output"]
        )

    outputs = pd.concat(out).reset_index()
    return outputs

# %%
# 8 obtain a binary of whether the patient has or hasnt received antibiotics by scanning to see if they
# received any of the common keywords for types of antibiotics

ANTIBIOTIC_KEYWORDS = [
    "cef", "ceph",
    "penicillin", "pip", "tazo",
    "vancomycin", "vanc",
    "levofloxacin", "ciprofloxacin",
    "meropenem", "imipenem",
    "azithromycin", "clarithromycin",
    "gentamicin", "amikacin",
    "clindamycin", "metronidazole",
    "doxycycline", "linezolid"
]

def build_prescriptions(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned prescription features (antibiotic exposure).

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | antibiotics
    """

    # Map ICU stays → admissions
    batch_meta = icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
    ][["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID", "INTIME", "OUTTIME"]]

    HADM_IDs = batch_meta.HADM_ID.unique()

    chunks = pd.read_csv(
        f"{DATA_DIR}/PRESCRIPTIONS.csv",
        usecols=[
            "SUBJECT_ID",
            "HADM_ID",
            "STARTDATE",
            "ENDDATE",
            "DRUG"
        ],
        chunksize=500_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch admissions
        df = df[df.HADM_ID.isin(HADM_IDs)]
        if df.empty:
            continue

        # 2. Identify antibiotics
        drug_lower = df["DRUG"].str.lower().fillna("")
        is_abx = drug_lower.apply(
            lambda x: any(k in x for k in ANTIBIOTIC_KEYWORDS)
        )
        df = df[is_abx]
        if df.empty:
            continue

        # 3. Parse times
        df["STARTDATE"] = pd.to_datetime(df["STARTDATE"])
        df["ENDDATE"] = pd.to_datetime(df["ENDDATE"])

        # If ENDDATE missing, assume one dose (common)
        df["ENDDATE"] = df["ENDDATE"].fillna(df["STARTDATE"])

        # 4. Attach ICU metadata
        df = df.merge(
            batch_meta,
            on=["SUBJECT_ID", "HADM_ID"],
            how="left"
        )

        # Drop prescriptions outside ICU stay
        df = df[
            (df.ENDDATE >= df.INTIME) &
            (df.STARTDATE <= df.OUTTIME)
        ]

        if df.empty:
            continue

        # 5. Expand prescription duration into bins
        rows = []

        for _, r in df.iterrows():
            start_bin = int(
                max(
                    0,
                    (r.STARTDATE - r.INTIME).total_seconds()
                    // (BIN_HOURS * 3600)
                )
            )
            end_bin = int(
                (r.ENDDATE - r.INTIME).total_seconds()
                // (BIN_HOURS * 3600)
            )

            for b in range(start_bin, end_bin + 1):
                rows.append({
                    "SUBJECT_ID": r.SUBJECT_ID,
                    "ICUSTAY_ID": r.ICUSTAY_ID,
                    "bin": b,
                    "antibiotics": 1
                })

        if rows:
            out.append(pd.DataFrame(rows))

    if not out:
        return pd.DataFrame(
            columns=["SUBJECT_ID", "ICUSTAY_ID", "bin", "antibiotics"]
        )

    # 6. Collapse duplicates
    prescriptions = (
        pd.concat(out, ignore_index=True)
        .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["antibiotics"]
        .max()
        .reset_index()
    )

    return prescriptions

# %%
# 9 perform batching and binning

icu_ids = np.sort(icu_meta.ICUSTAY_ID.unique())
batches = np.array_split(
    icu_ids,
    int(np.ceil(len(icu_ids) / BATCH_SIZE))
)

for i, batch_ids in enumerate(batches):
    print(f"Batch {i}: {len(batch_ids)} stays")

    batch_meta = icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ids)
    ]

    base = build_base_grid(batch_meta)
    vitals = build_vitals(batch_ids, icu_meta)
    labs = build_labs(batch_ids, icu_meta)
    inputs = build_inputs(batch_ids, icu_meta)
    #outputs = build_outputs(batch_ids, icu_meta)
    meds = build_prescriptions(batch_ids, icu_meta)

    df = base
    for feat in [vitals, labs, inputs, meds]:
        df = df.merge(
            feat,
            on=["SUBJECT_ID", "ICUSTAY_ID", "bin"],
            how="left"
        )

    df.to_parquet(
        f"{OUT_DIR}/batch_{i:02d}.parquet",
        index=False
    )
# Out:
# Batch 0: 2930 stays
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 17
#      12 batch_meta = icu_meta[
#      13     icu_meta.ICUSTAY_ID.isin(batch_ids)
#      14 ]
#      16 base = build_base_grid(batch_meta)
# ---> 17 vitals = build_vitals(batch_ids, icu_meta)
#      18 labs = build_labs(batch_ids, icu_meta)
#      19 inputs = build_inputs(batch_ids, icu_meta)
#
# Cell In[4], line 49, in build_vitals(batch_icustays, icu_meta)
#      41 chunks = pd.read_csv(
#      42     f"{DATA_DIR}/CHARTEVENTS.csv",
#      43     usecols=["SUBJECT_ID", "ICUSTAY_ID", "ITEMID", "CHARTTIME", "VALUENUM"],
#      44     chunksize=5_000_000
#      45 )
#      47 out = []
# ---> 49 for df in chunks:
#      50     df = df[df.ICUSTAY_ID.isin(batch_icustays)]
#      51     df = df[df.ITEMID.isin(ALL_VITAL_ITEMIDS)]
#
# ...

# %%
# 10 batch merging

files = glob.glob(f"{OUT_DIR}/batch_*.parquet")

full_df = pd.concat(
    (pd.read_parquet(f) for f in files),
    ignore_index=True
)

# %%
# 11 data cleaning and imputation

phys_cols = list(VITAL_ITEMIDS.keys())

full_df = full_df.sort_values(["ICUSTAY_ID", "bin"])
full_df["antibiotics"] = full_df["antibiotics"].fillna(0)
full_df[phys_cols] = (
    full_df.groupby("ICUSTAY_ID")[phys_cols]
    .ffill()
)

intervention_cols = []  # e.g. vasopressors, antibiotics
full_df[intervention_cols] = full_df[intervention_cols].fillna(0)

numeric_cols = full_df.select_dtypes(include="number").columns

for c in numeric_cols:
    lo = full_df[c].quantile(0.001)
    hi = full_df[c].quantile(0.999)
    full_df[c] = full_df[c].clip(lo, hi)

full_df["heart_rate"] = full_df["heart_rate"].clip(30, 220)
full_df["spo2"] = full_df["spo2"].clip(50, 100)
full_df["sbp"] = full_df["sbp"].clip(50, 180)
full_df["dbp"] = full_df["dbp"].clip(30, 140)

# %%
# 12 iterative Bayesian-Ridge imputation for residual gaps

imputer = IterativeImputer(
    estimator=BayesianRidge(),
    max_iter=10,
    random_state=0
)


full_df[numeric_cols] = imputer.fit_transform(
    full_df[numeric_cols]
)

# %%
# 13 data audit to check validity (no Nan and no Inf), then save

assert full_df.isna().sum().sum() == 0
assert np.isfinite(full_df[numeric_cols]).all().all()

full_df.to_parquet(MERGED_PATH, index=False)

# %%
# 14 load from parquet file (only needs to be run if you don't want to run all the code before this point)

full_df = pd.read_parquet(MERGED_PATH)

# %%
# 15 group data into sequences by stay

def build_sequences(full_df, state_cols, action_cols, id_col="ICUSTAY_ID", time_col="bin", return_ids=True):

    sequences = []
    ids = []

    # Ensure proper ordering
    df = full_df.sort_values(["SUBJECT_ID", id_col, time_col])

    for (SUBJECT_ID, ICUSTAY_ID), group in df.groupby(["SUBJECT_ID", "ICUSTAY_ID"]):
        group = group.sort_values(time_col)

        states = group[state_cols].to_numpy(dtype=np.float32)
        actions = group[action_cols].to_numpy(dtype=np.float32)

        T = len(group)

        # What I have come to the opinion of is this: the way the model is currently trained and loss is currently calculatedd
        # is totally fine and makes sense. Training a model to simply predict the next 1 step and then asking it to do that multiple 
        # times consecutively is totally fine and logical. All that I was ACTUALLY doing wrong was evaluating my RMSE incorrectly,
        # but that is an evaluation issue after training is already complete. As such, I am going to bank all of this, roll back a 
        # a bunch of my changes, and instead do a rework that allows for changing how I evaluate, not how I train.
        # Even so, still can only have a 3-step and 5-step prediction if there are at least that many future steps we can take.
        # I believe the best way to do this is to perform modifications at the end, in the RMSE function itself, not at the start.
        # So for now, I am reverting all changes made here
        if T < 2:
            continue
        seq = {
                "SUBJECT_ID": SUBJECT_ID,
                "ICUSTAY_ID": ICUSTAY_ID,
                "states": states[:-1],       # (T-1, 18)
                "actions": actions[:-1],     # (T-1, 3)
                "next_states": states[-1],   # (1, 18)
                "length": T - 1
            }

        sequences.append(seq)
    return sequences
    
state_features = [
    "heart_rate", "sbp", "dbp", "resp_rate", "spo2", "temperature",
    "gcs", "fio2", "o2_flow", "wbc", "platelets", "creatinine",
    "bilirubin", "lactate", "inr", "ph", "pco2", "po2"
]
action_features = [
    "iv_fluids", "vasopressors", "antibiotics"
]
feature_cols = state_features + action_features

sequences = build_sequences(full_df, state_features, action_features)
lengths = torch.tensor([b["length"] for b in sequences], dtype=torch.long)
max_len = lengths.max() #going to see if I can use this as a sort of global variable since i don'test_icu_ids
                        # think I can pass it to collate_fn

# %%
# 16 data split

def split_sequences_by_subject(sequences, seed=42):
    # Collect unique subjects
    subject_to_seqs = defaultdict(list)

    for seq in sequences:
        subject_to_seqs[seq["SUBJECT_ID"]].append(seq)

    subjects = list(subject_to_seqs.keys())

    # Shuffle subjects
    rng = np.random.default_rng(seed)
    rng.shuffle(subjects)

    # Split subjects
    N = len(subjects)
    n_train = int(0.70 * N)
    n_val = int(0.15 * N)

    train_subjects = set(subjects[:n_train]) # first 70%
    val_subjects   = set(subjects[n_train:n_train + n_val]) # the 15% from 70 to 85% range
    test_subjects  = set(subjects[n_train + n_val:]) # the 15% from 85 to 100% range

    # Assign sequences
    train_seqs = []
    val_seqs = []
    test_seqs = []

    for subj, seqs in subject_to_seqs.items():
        if subj in train_subjects:
            train_seqs.extend(seqs)
        elif subj in val_subjects:
            val_seqs.extend(seqs)
        elif subj in test_subjects:
            test_seqs.extend(seqs)
        else:
            raise RuntimeError("Subject not assigned to any split")

    return train_seqs, val_seqs, test_seqs

train_seqs, val_seqs, test_seqs = split_sequences_by_subject(sequences)
print("done")
# Out:
# done

# %%
# 17 scaling data

scaler = MinMaxScaler()
all_train_states = np.concatenate([s["states"] for s in sequences], axis=0)
scaler.fit(all_train_states)

def apply_scaler(seqs, scaler):
    out = []
    for s in seqs:
        s2 = dict(s)
        s2["states"] = scaler.transform(s["states"])
        next_temp = s["next_states"].reshape(1, -1)
        next_temp = scaler.transform(next_temp)
        next_temp = next_temp.squeeze(0)
        s2["next_states"] = next_temp
        out.append(s2)
    return out

train_seqs = apply_scaler(train_seqs, scaler)
val_seqs   = apply_scaler(val_seqs, scaler)
test_seqs  = apply_scaler(test_seqs, scaler)

# %%
def check_nan(split, name):
    for i, s in enumerate(split):
        if np.isnan(s["states"]).any():
            print(f"NaN in {name} states seq {i}")
        if np.isnan(s["actions"]).any():
            print(f"NaN in {name} actions seq {i}")
        if np.isinf(s["states"]).any():
            print(f"NaN in {name} states seq {i}")
        if np.isinf(s["actions"]).any():
            print(f"NaN in {name} actions seq {i}")

check_nan(train_seqs, "train")
check_nan(val_seqs, "val")
check_nan(test_seqs, "test")
assert not np.isnan(all_train_states).any()
assert not np.isinf(all_train_states).any()

# %%
# 18

class ICUDataset(Dataset):
    def __init__(self, sequences):
        self.seqs = sequences

    def __len__(self):
        return len(self.seqs)

    def __getitem__(self, idx):
        s = self.seqs[idx]

        return {
            "states": torch.tensor(s["states"], dtype=torch.float32),
            "actions": torch.tensor(s["actions"], dtype=torch.float32),
            "next_states": torch.tensor(s["next_states"], dtype=torch.float32),
            "length": s["length"]
            }   


def collate_fn(batch):
    lengths = torch.tensor([b["length"] for b in batch], dtype=torch.long)
    #max_len = lengths.max()

    def pad(x):
        out = torch.zeros(len(batch), max_len, x[0].shape[-1])
        for i, b in enumerate(x):
            out[i, :b.shape[0]] = b
        return out

    states = pad([b["states"] for b in batch])
    actions = pad([b["actions"] for b in batch])
    next_states = ([b["next_states"] for b in batch])
    next_states = torch.stack(next_states)

    mask = torch.arange(max_len)[None, :] < lengths[:, None]

    return states, actions, next_states, mask, lengths

# %%
# GRU model setup

class GRUModel(nn.Module):
    def __init__(self, state_dim=18, action_dim=3, hidden=128, layers=2):
        super(GRUModel, self).__init__()
        self.flatten = nn.Flatten()
        self.gru = nn.GRU(7266, hidden, layers, batch_first=True)
        self.out = nn.Linear(hidden, state_dim)
        self.relu = nn.ReLU()

    def forward(self, s, a):
        x = torch.cat([s, a], dim=-1)
        x = self.flatten(x)
        out, _ = self.gru(x)
        out = self.out(out)
        out = self.relu(out)
        return out

# %%
# 19 LSTM model setup

class LSTMModel(nn.Module):
    def __init__(self, state_dim=18, action_dim=3, hidden=128, layers=2):
        super(LSTMModel, self).__init__()
        self.flatten = nn.Flatten()
        self.lstm = nn.LSTM(7266, hidden, layers, batch_first=True)
        self.out = nn.Linear(hidden, state_dim)
        #self.relu = nn.ReLU()

    def forward(self, s, a):
        x = torch.cat([s, a], dim=-1)
        x = self.flatten(x)
        out, _ = self.lstm(x)
        out = self.out(out)
        #out = self.relu(out)
        return out

# %%
# 20 CFC model setup

class CfCCell(nn.Module):
    """
    Closed-form Continuous-time (CfC) Neural Network Cell
    
    Implements a liquid time-constant network with closed-form solutions
    to the underlying ODEs for efficient computation.
    """
    
    def __init__(self, input_size, hidden_size):
        super(CfCCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size

        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
        
        # Learnable parameters for the ODE dynamics
        self.ff1 = nn.Linear(input_size + hidden_size, hidden_size)
        self.ff2 = nn.Linear(input_size + hidden_size, hidden_size)
        self.time_a = nn.Linear(input_size + hidden_size, hidden_size)
        self.time_b = nn.Linear(input_size + hidden_size, hidden_size)

        #self.relu = nn.ReLU()
        
    def forward(self, x, h, dt=1.0):
        """
        Forward pass through the CfC cell
        
        Args:
            x: Input tensor of shape (batch_size, input_size)
            h: Hidden state tensor of shape (batch_size, hidden_size)
            dt: Time step (default=1.0)
            
        Returns:
            new_h: Updated hidden state
        """
        #batch_size, seq_len, _ = x.size()
        #device = x.device
        #all_h = torch.zeros(batch_size, seq_len, self.hidden_size, device=device)
        #for t in range(seq_len):
        # Concatenate input and hidden state
        combined = torch.cat([x, h], dim=1)
        
        # Compute the ODE parameters
        # f(x,h) represents the target value the state wants to reach
        ff1 = self.tanh(self.ff1(combined))
        ff2 = self.tanh(self.ff2(combined))
        t_a = self.time_a(combined)
        t_b = self.time_b(combined)
        
        #t_interp = self.sigmoid(t_a * ts + t_b)

        # Time constant (how fast the state changes)
        # Using softplus to ensure positivity
        tau = F.softplus(t_a) + 0.1  # Add small constant for stability
        
        # Input modulation
        #input_gate = torch.sigmoid(t_b)
        
        # Closed-form solution to the ODE: dh/dt = (f - h) / tau
        # Solution: h(t+dt) = f + (h(t) - f) * exp(-dt/tau)
        decay = torch.exp(-dt / tau)
        #new_h = f + (h - f) * decay
        t_interp = self.sigmoid(t_a * decay + t_b)
        # Apply input modulation
        #new_h = input_gate * new_h + (1 - input_gate) * h
        new_h = ff1 * (1.0 - t_interp) + t_interp * ff2
        #all_h[:,t,:] = h

        #new_h = self.relu(new_h)
        
        return new_h


class CfCNetwork(nn.Module):
    """
    Complete CfC Neural Network for sequence processing
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2, dt=1.0):
        super(CfCNetwork, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.dt = dt
        
        self.flatten = nn.Flatten()

        # Stack of CfC cells
        self.cells = nn.ModuleList()
        for i in range(num_layers):
            cell_input_size = input_size*346 if i == 0 else hidden_size
            self.cells.append(CfCCell(cell_input_size, hidden_size))
        
        # Output layer
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden=None):
        """
        Forward pass through the network
        
        Args:
            x: Input tensor of shape (batch_size, seq_len, input_size)
            hidden: Initial hidden states (optional)
            dt: Time step
            
        Returns:
            outputs: Output tensor of shape (batch_size, seq_len, output_size)
            hidden: Final hidden states
        """
        batch_size, seq_len, _ = x.size()

        x = self.flatten(x)
        
        # Initialize hidden states if not provided
        if hidden is None:
            hidden = [torch.zeros(batch_size, self.hidden_size, device=x.device) 
                     for _ in range(self.num_layers)]
        
        outputs = []
        
        # Process sequence
        for t in range(1):
            layer_input = x
            
            # Pass through each layer
            for i, cell in enumerate(self.cells):
                hidden[i] = cell(layer_input, hidden[i], self.dt)
                layer_input = hidden[i]
            
            # Generate output
            output = self.fc_out(hidden[-1])
            outputs.append(output)
        
        # Stack outputs
        outputs = torch.stack(outputs, dim=0)
        #outputs = self.fc_out(outputs)

        '''layer_input = x
        
        # Process each layer
        for i, cell in enumerate(self.cells):
            layer_output = cell(layer_input, hidden[i], self.dt)
            layer_input = layer_output
            hidden[i] = layer_output[:, -1, :]  # Final hidden state
        
        # Apply output layer to all timesteps at once
        outputs = self.fc_out(layer_output)'''
        
        return outputs

# %%
# CFC internal architecture 2

class CfCCell2(nn.Module):
    """
    Closed-form Continuous-time (CfC) Neural Network Cell
    
    Implements a liquid time-constant network with closed-form solutions
    to the underlying ODEs for efficient computation.
    """
    
    def __init__(self, input_size, hidden_size):
        super(CfCCell2, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size

        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
        
        # Learnable parameters for the ODE dynamics
        self.ff1 = nn.Linear(input_size + hidden_size, hidden_size)
        self.ff2 = nn.Linear(input_size + hidden_size, hidden_size)
        self.time_a = nn.Linear(input_size + hidden_size, hidden_size)
        self.time_b = nn.Linear(input_size + hidden_size, hidden_size)
        
    def forward(self, x, h, dt=1.0):
        """
        Forward pass through the CfC cell
        
        Args:
            x: Input tensor of shape (batch_size, input_size)
            h: Hidden state tensor of shape (batch_size, hidden_size)
            dt: Time step (default=1.0)
            
        Returns:
            new_h: Updated hidden state
        """
        # Concatenate input and hidden state
        combined = torch.cat([x, h], dim=1)
        
        # Compute the ODE parameters
        # f(x,h) represents the target value the state wants to reach
        f = torch.tanh(self.ff1(combined)) + torch.tanh(self.ff2(combined))
        
        # Time constant (how fast the state changes)
        # Using softplus to ensure positivity
        tau = F.softplus(self.time_a(combined)) + 0.1  # Add small constant for stability
        
        # Input modulation
        input_gate = torch.sigmoid(self.time_b(combined))
        
        # Closed-form solution to the ODE: dh/dt = (f - h) / tau
        # Solution: h(t+dt) = f + (h(t) - f) * exp(-dt/tau)
        decay = torch.exp(-dt / tau)
        new_h = f + (h - f) * decay
        
        # Apply input modulation
        new_h = input_gate * new_h + (1 - input_gate) * h
        
        return new_h


class CfCNetwork2(nn.Module):
    """
    Complete CfC Neural Network for sequence processing
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2, dt=1.0):
        super(CfCNetwork2, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.dt = dt

        self.flatten = nn.Flatten()
        
        # Stack of CfC cells
        self.cells = nn.ModuleList()
        for i in range(num_layers):
            cell_input_size = input_size*346 if i == 0 else hidden_size
            self.cells.append(CfCCell2(cell_input_size, hidden_size))
        
        # Output layer
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden=None):
        """
        Forward pass through the network
        
        Args:
            x: Input tensor of shape (batch_size, seq_len, input_size)
            hidden: Initial hidden states (optional)
            dt: Time step
            
        Returns:
            outputs: Output tensor of shape (batch_size, seq_len, output_size)
            hidden: Final hidden states
        """
        batch_size, seq_len, _ = x.size()
        
        x = self.flatten(x)

        # Initialize hidden states if not provided
        if hidden is None:
            hidden = [torch.zeros(batch_size, self.hidden_size, device=x.device) 
                     for _ in range(self.num_layers)]
        
        outputs = []
        
        # Process sequence
        for t in range(1):
            layer_input = x
            
            # Pass through each layer
            for i, cell in enumerate(self.cells):
                hidden[i] = cell(layer_input, hidden[i], self.dt)
                layer_input = hidden[i]
            
            # Generate output
            output = self.fc_out(hidden[-1])
            outputs.append(output)
        
        # Stack outputs
        outputs = torch.stack(outputs, dim=0)
        #outputs = self.fc_out(outputs)
        
        return outputs

# %%
# CFC Architecture 3, most loyal to original CfC github

class CfCCell3(nn.Module):
    """
    Closed-form Continuous-time (CfC) Neural Network Cell
    
    Implements a liquid time-constant network with closed-form solutions
    to the underlying ODEs for efficient computation.
    """
    
    def __init__(self, input_size, hidden_size, num_layers):
        super(CfCCell3, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        layer_list = [
            nn.Linear(input_size + hidden_size, hidden_size),
            nn.ReLU(),
        ]
        for i in range(1, num_layers):
            layer_list.append(
                nn.Linear(
                    hidden_size, hidden_size
                )
            )
            layer_list.append(nn.ReLU())

        self.backbone = nn.Sequential(*layer_list)
        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()

        self.ff1 = nn.Linear(hidden_size, hidden_size)
        self.ff2 = nn.Linear(hidden_size, hidden_size)
        self.time_a = nn.Linear(hidden_size, hidden_size)
        self.time_b = nn.Linear(hidden_size, hidden_size)
        
    def forward(self, input, hx, dt=1.0):
        """
        Forward pass through the CfC cell
        
        Args:
            x: Input tensor of shape (batch_size, input_size)
            h: Hidden state tensor of shape (batch_size, hidden_size)
            dt: Time step (default=1.0)
            
        Returns:
            new_h: Updated hidden state
        """
        # Concatenate input and hidden state
        #batch_size = input.size(0)
        x = torch.cat([input, hx], dim=1)
        x = self.backbone(x)
        
        # Compute the ODE parameters
   
        ff1 = self.tanh(self.ff1(x))
        ff2 = self.tanh(self.ff2(x))
        t_a = self.time_a(x)
        t_b = self.time_b(x)
        
        tau = F.softplus(t_a) + 0.1
        decay = torch.exp(-dt / tau)
        t_interp = self.sigmoid(t_a * decay + t_b)

        new_hidden = ff1 * (1.0 - t_interp) + t_interp * ff2
        
        return new_hidden


class CfCNetwork3(nn.Module):
    """
    Complete CfC Neural Network for sequence processing
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2, dt=1.0):
        super(CfCNetwork3, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.dt = dt
        
        # Single cell that counts for multiple
        self.cells = CfCCell3(input_size*346, hidden_size, num_layers)
        
        self.flatten = nn.Flatten()

        # Output layer
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden=None):
        """
        Forward pass through the network
        
        Args:
            x: Input tensor of shape (batch_size, seq_len, input_size)
            hidden: Initial hidden states (optional)
            dt: Time step
            
        Returns:
            outputs: Output tensor of shape (batch_size, seq_len, output_size)
            hidden: Final hidden states
        """
        batch_size, seq_len, _ = x.size()

        x = self.flatten(x)
        
        # Initialize hidden states if not provided
        if hidden is None:
            hidden = torch.zeros((batch_size, self.hidden_size), device=x.device)
        
        outputs = []
        
        # Process sequence
        for t in range(1):
            layer_input = x
            hidden = self.cells.forward(layer_input, hidden, self.dt)
            outputs.append(self.fc_out(hidden))
        
        # Stack outputs
        outputs = torch.stack(outputs, dim=0)
        
        return outputs

# %%
# LTC model

class LTCCell(nn.Module):
    """
    Liquid Time-Constant (LTC) Neural Network Cell
    
    Implements a continuous-time RNN with learnable time constants
    and uses numerical ODE integration (Euler method by default).
    """
    
    def __init__(self, input_size, hidden_size, ode_unfolds=6):
        super(LTCCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.ode_unfolds = ode_unfolds  # Number of ODE solver steps
        
        # Input layer
        self.input_layer = nn.Linear(input_size, hidden_size)
        
        # Recurrent weights (hidden-to-hidden)
        self.recurrent_layer = nn.Linear(hidden_size, hidden_size, bias=False)
        
        # Time constants (one per hidden unit)
        # Using a learnable parameter that will be transformed to positive values
        self.tau = nn.Parameter(torch.rand(hidden_size))
        
        # Bias term
        self.bias = nn.Parameter(torch.zeros(hidden_size))
        
    def forward(self, x, h, dt=1.0):
        """
        Forward pass through the LTC cell using numerical ODE integration
        
        Args:
            x: Input tensor of shape (batch_size, input_size)
            h: Hidden state tensor of shape (batch_size, hidden_size)
            dt: Time step (default=1.0)
            
        Returns:
            new_h: Updated hidden state
        """
        # Effective time step for ODE solver
        step_size = dt / self.ode_unfolds
        
        # Compute time constants (ensure they're positive)
        tau = F.softplus(self.tau) + 0.1
        
        # Euler integration over multiple steps
        current_h = h
        for _ in range(self.ode_unfolds):
            # Compute input contribution
            input_contrib = self.input_layer(x)
            
            # Compute recurrent contribution
            recurrent_contrib = self.recurrent_layer(current_h)
            
            # Total input to the system
            total_input = input_contrib + recurrent_contrib + self.bias
            
            # Apply activation
            f = torch.tanh(total_input)
            
            # ODE: dh/dt = (f - h) / tau
            # Euler step: h(t+dt) = h(t) + dt * dh/dt
            dh_dt = (f - current_h) / tau
            current_h = current_h + step_size * dh_dt
        
        return current_h


class RungeKuttaLTCCell(nn.Module):
    """
    LTC Cell with Runge-Kutta 4 (RK4) integration for better accuracy
    More computationally expensive but more stable
    """
    
    def __init__(self, input_size, hidden_size):
        super(RungeKuttaLTCCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        
        self.input_layer = nn.Linear(input_size, hidden_size)
        self.recurrent_layer = nn.Linear(hidden_size, hidden_size, bias=False)
        self.tau = nn.Parameter(torch.rand(hidden_size))
        self.bias = nn.Parameter(torch.zeros(hidden_size))
        
    def _f(self, x, h):
        """Compute the derivative function"""
        tau = F.softplus(self.tau) + 0.1
        
        input_contrib = self.input_layer(x)
        recurrent_contrib = self.recurrent_layer(h)
        total_input = input_contrib + recurrent_contrib + self.bias
        f = torch.tanh(total_input)
        
        # dh/dt = (f - h) / tau
        dh_dt = (f - h) / tau
        return dh_dt
    
    def forward(self, x, h, dt=1.0):
        """
        Forward pass using RK4 integration
        
        Args:
            x: Input tensor of shape (batch_size, input_size)
            h: Hidden state tensor of shape (batch_size, hidden_size)
            dt: Time step
            
        Returns:
            new_h: Updated hidden state
        """
        # RK4 method
        k1 = self._f(x, h)
        k2 = self._f(x, h + 0.5 * dt * k1)
        k3 = self._f(x, h + 0.5 * dt * k2)
        k4 = self._f(x, h + dt * k3)
        
        # Weighted average
        new_h = h + (dt / 6.0) * (k1 + 2*k2 + 2*k3 + k4)
        
        return new_h


class LTCNetwork(nn.Module):
    """
    Complete Liquid Time-Constant Neural Network
    
    Uses the same interface as CfCNetwork for easy comparison
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2, 
                 solver='euler', ode_unfolds=6, dt=1.0):
        super(LTCNetwork, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.solver = solver
        self.dt = dt
        
        # Stack of LTC cells
        self.cells = nn.ModuleList()
        for i in range(num_layers):
            cell_input_size = input_size*346 if i == 0 else hidden_size
            
            if solver == 'euler':
                self.cells.append(LTCCell(cell_input_size, hidden_size, ode_unfolds))
            elif solver == 'rk4':
                self.cells.append(RungeKuttaLTCCell(cell_input_size, hidden_size))
            else:
                raise ValueError(f"Unknown solver: {solver}. Use 'euler' or 'rk4'")
        
        self.flatten = nn.Flatten()

        # Output layer
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden=None):
        """
        Forward pass through the network
        
        Args:
            x: Input tensor of shape (batch_size, seq_len, input_size)
            hidden: Initial hidden states (optional)
            dt: Time step
            
        Returns:
            outputs: Output tensor of shape (batch_size, seq_len, output_size)
            hidden: Final hidden states
        """
        batch_size, seq_len, _ = x.size()
        device = x.device

        x = self.flatten(x)
        
        # Initialize hidden states if not provided
        if hidden is None:
            hidden = [torch.zeros(batch_size, self.hidden_size, device=device) 
                     for _ in range(self.num_layers)]
        
        outputs = []
        
        # Process sequence
        for t in range(1):
            layer_input = x
            
            # Pass through each layer
            for i, cell in enumerate(self.cells):
                hidden[i] = cell(layer_input, hidden[i], self.dt)
                layer_input = hidden[i]
            
            # Generate output
            output = self.fc_out(hidden[-1])
            outputs.append(output)
        
        # Stack outputs
        outputs = torch.stack(outputs, dim=0)
        
        return outputs


class OptimizedLTCNetwork(nn.Module):
    """
    Memory-optimized LTC Network that pre-allocates output tensors
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2, 
                 solver='euler', ode_unfolds=6):
        super(OptimizedLTCNetwork, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        self.cells = nn.ModuleList()
        for i in range(num_layers):
            cell_input_size = input_size*346 if i == 0 else hidden_size
            
            if solver == 'euler':
                self.cells.append(LTCCell(cell_input_size, hidden_size, ode_unfolds))
            elif solver == 'rk4':
                self.cells.append(RungeKuttaLTCCell(cell_input_size, hidden_size))
            else:
                raise ValueError(f"Unknown solver: {solver}")
        
        self.flatten = nn.Flatten()

        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden=None, dt=1.0):
        """Optimized forward pass"""
        batch_size, seq_len, _ = x.size()
        device = x.device

        x = self.flatten(x)

        if hidden is None:
            hidden = [torch.zeros(batch_size, self.hidden_size, device=device) 
                     for _ in range(self.num_layers)]
        
        # Pre-allocate output tensor
        all_outputs = torch.zeros(batch_size, seq_len, self.output_size, device=device)
        
        for t in range(1):
            layer_input = x
            
            for i, cell in enumerate(self.cells):
                hidden[i] = cell(layer_input, hidden[i], dt)
                layer_input = hidden[i]
            
            all_outputs = self.fc_out(hidden[-1])
        
        return all_outputs

# %%
# Liquid-resistance Liquid-Capacitance Network setup

class LRCCell(nn.Module):
    """
    Liquid-Resistance Liquid-Capacitance (LRC) Neural Network Cell
    
    Models neurons as RC circuits where:
    - R (Resistance): Controls how much current flows (input sensitivity)
    - C (Capacitance): Controls how quickly voltage changes (memory)
    - The dynamics follow: C * dV/dt = (I - V) / R
    
    This can be rewritten as: dV/dt = (I - V) / (R*C) = (I - V) / tau
    where tau = R*C is the time constant
    """
    
    def __init__(self, input_size, hidden_size, ode_unfolds=6):
        super(LRCCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.ode_unfolds = ode_unfolds
        
        # Input projection (computes the "current" I)
        self.input_layer = nn.Linear(input_size, hidden_size)
        
        # Recurrent connection
        self.recurrent_layer = nn.Linear(hidden_size, hidden_size, bias=False)
        
        # Learnable resistance and capacitance for each neuron
        # These will be transformed to positive values
        self.resistance = nn.Parameter(torch.rand(hidden_size))
        self.capacitance = nn.Parameter(torch.rand(hidden_size))
        
        # Bias (resting potential)
        self.bias = nn.Parameter(torch.zeros(hidden_size))
        
    def forward(self, x, v, dt=1.0):
        """
        Forward pass through the LRC cell
        
        Args:
            x: Input tensor of shape (batch_size, input_size)
            v: Voltage state (hidden state) of shape (batch_size, hidden_size)
            dt: Time step (default=1.0)
            
        Returns:
            new_v: Updated voltage state
        """
        # Ensure positive resistance and capacitance
        R = F.softplus(self.resistance) + 0.1
        C = F.softplus(self.capacitance) + 0.1
        
        # Time constant tau = R * C
        tau = R * C
        
        # Effective step size for numerical integration
        step_size = dt / self.ode_unfolds
        
        # Euler integration
        current_v = v
        for _ in range(self.ode_unfolds):
            # Compute input current
            input_current = self.input_layer(x)
            
            # Recurrent current
            recurrent_current = self.recurrent_layer(current_v)
            
            # Total current with bias
            total_current = input_current + recurrent_current + self.bias
            
            # Apply activation to get target voltage
            I = torch.tanh(total_current)
            
            # RC circuit dynamics: dV/dt = (I - V) / tau
            dv_dt = (I - current_v) / tau
            
            # Euler step
            current_v = current_v + step_size * dv_dt
        
        return current_v


class AdvancedLRCCell(nn.Module):
    """
    Advanced LRC Cell with voltage-dependent resistance (like real neurons)
    
    Implements non-linear resistance that changes based on membrane voltage,
    modeling phenomena like voltage-gated ion channels.
    """
    
    def __init__(self, input_size, hidden_size, ode_unfolds=6):
        super(AdvancedLRCCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.ode_unfolds = ode_unfolds
        
        # Input and recurrent connections
        self.input_layer = nn.Linear(input_size, hidden_size)
        self.recurrent_layer = nn.Linear(hidden_size, hidden_size, bias=False)
        
        # Base resistance and capacitance
        self.base_resistance = nn.Parameter(torch.rand(hidden_size))
        self.capacitance = nn.Parameter(torch.rand(hidden_size))
        
        # Voltage-dependent resistance modulation
        self.resistance_modulation = nn.Linear(hidden_size, hidden_size)
        
        self.bias = nn.Parameter(torch.zeros(hidden_size))
        
    def forward(self, x, v, dt=1.0):
        """Forward pass with voltage-dependent resistance"""
        # Base values
        R_base = F.softplus(self.base_resistance) + 0.1
        C = F.softplus(self.capacitance) + 0.1
        
        step_size = dt / self.ode_unfolds
        current_v = v
        
        for _ in range(self.ode_unfolds):
            # Voltage-dependent resistance (simulates ion channels)
            R_modulation = torch.sigmoid(self.resistance_modulation(current_v))
            R = R_base * (0.5 + R_modulation)  # R varies between 0.5*R_base and 1.5*R_base
            
            tau = R * C
            
            # Compute currents
            input_current = self.input_layer(x)
            recurrent_current = self.recurrent_layer(current_v)
            total_current = input_current + recurrent_current + self.bias
            I = torch.tanh(total_current)
            
            # RC dynamics
            dv_dt = (I - current_v) / tau
            current_v = current_v + step_size * dv_dt
        
        return current_v


class LRCNetwork(nn.Module):
    """
    Complete Liquid-Resistance Liquid-Capacitance Neural Network
    
    Uses the same interface as CfCNetwork for easy comparison
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2, 
                 cell_type='basic', ode_unfolds=6):
        super(LRCNetwork, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.cell_type = cell_type
        
        # Stack of LRC cells
        self.cells = nn.ModuleList()
        for i in range(num_layers):
            cell_input_size = input_size if i == 0 else hidden_size
            
            if cell_type == 'basic':
                self.cells.append(LRCCell(cell_input_size, hidden_size, ode_unfolds))
            elif cell_type == 'advanced':
                self.cells.append(AdvancedLRCCell(cell_input_size, hidden_size, ode_unfolds))
            else:
                raise ValueError(f"Unknown cell_type: {cell_type}. Use 'basic' or 'advanced'")
        
        # Output layer
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, voltage=None, dt=1.0):
        """
        Forward pass through the network
        
        Args:
            x: Input tensor of shape (batch_size, seq_len, input_size)
            voltage: Initial voltage states (optional)
            dt: Time step
            
        Returns:
            outputs: Output tensor of shape (batch_size, seq_len, output_size)
            voltage: Final voltage states
        """
        batch_size, seq_len, _ = x.size()
        device = x.device
        
        # Initialize voltage states if not provided
        if voltage is None:
            voltage = [torch.zeros(batch_size, self.hidden_size, device=device) 
                      for _ in range(self.num_layers)]
        
        outputs = []
        
        # Process sequence
        for t in range(seq_len):
            layer_input = x[:, t, :]
            
            # Pass through each layer
            for i, cell in enumerate(self.cells):
                voltage[i] = cell(layer_input, voltage[i], dt)
                layer_input = voltage[i]
            
            # Generate output
            output = self.fc_out(voltage[-1])
            outputs.append(output)
        
        # Stack outputs
        outputs = torch.stack(outputs, dim=1)
        
        return outputs
    
    def get_circuit_parameters(self):
        """
        Get the learned resistance and capacitance values
        Useful for analysis and visualization
        """
        params = []
        for i, cell in enumerate(self.cells):
            R = F.softplus(cell.resistance if hasattr(cell, 'resistance') 
                          else cell.base_resistance) + 0.1
            C = F.softplus(cell.capacitance) + 0.1
            tau = R * C
            
            params.append({
                'layer': i,
                'resistance': R.detach().cpu(),
                'capacitance': C.detach().cpu(),
                'time_constant': tau.detach().cpu()
            })
        
        return params


class OptimizedLRCNetwork(nn.Module):
    """
    Memory-optimized LRC Network
    """
    
    def __init__(self, input_size=21, hidden_size=128, output_size=18, num_layers=2, 
                 cell_type='basic', ode_unfolds=6):
        super(OptimizedLRCNetwork, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        self.cells = nn.ModuleList()
        for i in range(num_layers):
            cell_input_size = input_size if i == 0 else hidden_size
            
            if cell_type == 'basic':
                self.cells.append(LRCCell(cell_input_size, hidden_size, ode_unfolds))
            elif cell_type == 'advanced':
                self.cells.append(AdvancedLRCCell(cell_input_size, hidden_size, ode_unfolds))
            else:
                raise ValueError(f"Unknown cell_type: {cell_type}")
        
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, voltage=None, dt=1.0):
        """Optimized forward pass"""
        batch_size, seq_len, _ = x.size()
        device = x.device
        
        if voltage is None:
            voltage = [torch.zeros(batch_size, self.hidden_size, device=device) 
                      for _ in range(self.num_layers)]
        
        # Pre-allocate output tensor
        all_outputs = torch.zeros(batch_size, seq_len, self.output_size, device=device)
        
        for t in range(seq_len):
            layer_input = x[:, t, :]
            
            for i, cell in enumerate(self.cells):
                voltage[i] = cell(layer_input, voltage[i], dt)
                layer_input = voltage[i]
            
            all_outputs[:, t, :] = self.fc_out(voltage[-1])
        
        return all_outputs

# %%
# 21 error for prediction vs actual true next states

def masked_mse(pred, target, mask):
    mask = mask.unsqueeze(-1)
    if mask.sum() == 0:
        print("Oh no")
    err = (pred - target) ** 2
    #torch.sqrt(err.sum() / (ns.size(0) * err.shape[-1]))
    return torch.sqrt((err).sum() / (target.size(0) * err.shape[-1]))

# %%
# 22 define our own train model function so we can control for training differences between models

def train_model(model, train_loader, val_loader, best_save, epochs=30, lr=2e-3, device="cuda"):
    model.to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    scaler = GradScaler(device="cuda")

    best_val = float("inf")
    early_stop = 10
    for epoch in range(epochs):
        model.train()

        for s, a, ns, mask, _ in train_loader:
            s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)

            if best_save == "best_gru.pt" or best_save == "best_lstm.pt":
                pred = model(s, a)
            else:
                x = torch.cat([s, a], dim=-1)
                pred = model(x)
            loss = masked_mse(pred, ns, mask)

            opt.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(opt)
            scaler.update()

        # Validation
        model.eval()
        with torch.no_grad():
            vals = []
            for s, a, ns, mask, _ in val_loader:
                s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)
                if best_save == "best_gru.pt" or best_save == "best_lstm.pt":
                    pred = model(s, a)
                else:
                    x = torch.cat([s, a], dim=-1)
                    pred = model(x)
                vals.append(masked_mse(pred, ns, mask).item())

            val_loss = np.mean(vals)

        print(f"Epoch {epoch}: val loss={val_loss:.5f}")

        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), best_save)
            early_stop = 10
        '''else:
            early_stop -= 1
            if early_stop == 0:
                # break should cause function to exit early and finish training.
                # This can allow us to do more epochs without concern.
                break'''

# %%
# 23 calculate the RMSE as an evaluation metric between models

def rollout_rmse(model, loader, K, model_type, device="cuda"):
    model.eval()
    rmses = []

    with torch.no_grad():
        for s, a, ns, mask, lengths in loader:
            s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)
            cur = s.clone()
            cur = cur.to(device)

            # we can't just exclude a whole batch if min_length is too small bc then they all get excluded.
            # So, we have to remove each stay in the batch with a length that is too small
            act = a
            if K > 1:
                temp_cur = []
                temp_ns = []
                temp_lengths = []
                temp_act = []
                changed = False
                for stay, target, action, length in zip(cur, ns, act, lengths):
                    if length > K:
                        temp_cur.append(stay)
                        temp_lengths.append(length)
                        temp_ns.append(target)
                        temp_act.append(action)
                        changed = True
                if changed:
                    cur = torch.stack(temp_cur, dim=0)
                    lengths = torch.stack(temp_lengths, dim=0)
                    ns = torch.stack(temp_ns, dim=0)
                    act = torch.stack(temp_act, dim=0)
                else:
                    continue
                for i, length in enumerate(lengths):
                    pad1 = torch.zeros(K-1, cur[0].shape[-1])
                    cur[i, length-K+1:length] = pad1
                
            for k in range(K):
                if model_type == "gru" or model_type == "lstm":
                    pred = model(cur, act)
                else:
                    x = torch.cat([cur, act], dim=-1)
                    pred = model(x)
                idx = lengths-K+1
                batch_indices = torch.arange(ns.size(0), device=ns.device)
                cur[batch_indices, idx] = pred

            last_ns = ns
            last_cur = pred

            err = (last_cur - last_ns) ** 2

            # used to divide by mask_f.sum(), which is representative of the total number of sequences present for prediction.
            # this number would have been the same as lengths.sum(), but in our current code state, our lengths.sum() changes
            # as our code executes to stay more true to our final outcome. Even so, we cannot use our lengths.sum(), as we only 
            # compare the last state for each sequence. so it becomes about how many batches we actually have left x 1 each.
            rmse = torch.sqrt(err.sum() / (ns.size(0) * err.shape[-1]))
            rmses.append(rmse.item())

    return np.mean(rmses)

# %%
# 24 function to load everything up and train a model

def run_experiment(train_seqs, val_seqs, test_seqs, model_type, best_save, dt=1.0):
    train_ds = ICUDataset(train_seqs)
    val_ds = ICUDataset(val_seqs)
    test_ds = ICUDataset(test_seqs)

    train_loader = DataLoader(train_ds, batch_size=16, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_ds, batch_size=16, collate_fn=collate_fn)
    test_loader = DataLoader(test_ds, batch_size=16, collate_fn=collate_fn)

    if model_type == "gru":
        model = GRUModel()
    elif model_type == "cfc":
        model = CfCNetwork(dt=dt)
    elif model_type == "ltc":
        model = OptimizedLTCNetwork(solver="rk4")
    elif model_type == "cfc2":
        model = CfCNetwork2(dt=dt)
    elif model_type == "cfc3":
        model = CfCNetwork3(dt=dt)
    else:
        model = LSTMModel()
    
    #comment out the below line before running if you wish ti simpkly load the model and test it, rather than train it
    train_model(model, train_loader, val_loader, best_save)

    model.load_state_dict(torch.load(best_save))
    model.to("cuda")

    print("1-step RMSE:", rollout_rmse(model, test_loader, 1, model_type))
    print("3-step RMSE:", rollout_rmse(model, test_loader, 3, model_type))
    print("5-step RMSE:", rollout_rmse(model, test_loader, 5, model_type))

# %%
# 25 call experiment on GRU

print("Training GRU")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="gru", best_save="best_gru.pt")
# Out:
# Training GRU
# Epoch 0: val loss=0.06433
# Epoch 1: val loss=0.06184
# Epoch 2: val loss=0.06089
# Epoch 3: val loss=0.06054
# Epoch 4: val loss=0.06013
# Epoch 5: val loss=0.06003
# Epoch 6: val loss=0.05975
# Epoch 7: val loss=0.05926
# Epoch 8: val loss=0.05923
# Epoch 9: val loss=0.05933
# Epoch 10: val loss=0.05962
# Epoch 11: val loss=0.05942
# Epoch 12: val loss=0.05782
# Epoch 13: val loss=0.05849
# Epoch 14: val loss=0.05983
# Epoch 15: val loss=0.05800
# Epoch 16: val loss=0.06025
# Epoch 17: val loss=0.05830
# Epoch 18: val loss=0.05878
# Epoch 19: val loss=0.05854
# Epoch 20: val loss=0.05929
# Epoch 21: val loss=0.05965
# Epoch 22: val loss=0.05797
# Epoch 23: val loss=0.05934
# Epoch 24: val loss=0.05888
# Epoch 25: val loss=0.05798
# Epoch 26: val loss=0.05814
# Epoch 27: val loss=0.05879
# Epoch 28: val loss=0.05841
# Epoch 29: val loss=0.05866
# ...

# %%
# call experiment on LSTM

print("Training LSTM")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="lstm", best_save="best_lstm.pt")
# Out:
# Training LSTM
# Epoch 0: val loss=0.06349
# Epoch 1: val loss=0.06146
# Epoch 2: val loss=0.05987
# Epoch 3: val loss=0.05911
# Epoch 4: val loss=0.05800
# Epoch 5: val loss=0.05766
# Epoch 6: val loss=0.05804
# Epoch 7: val loss=0.05776
# Epoch 8: val loss=0.05731
# Epoch 9: val loss=0.05703
# Epoch 10: val loss=0.05684
# Epoch 11: val loss=0.05702
# Epoch 12: val loss=0.05694
# Epoch 13: val loss=0.05626
# Epoch 14: val loss=0.05656
# Epoch 15: val loss=0.05673
# Epoch 16: val loss=0.05682
# Epoch 17: val loss=0.05634
# Epoch 18: val loss=0.05639
# Epoch 19: val loss=0.05670
# Epoch 20: val loss=0.05642
# Epoch 21: val loss=0.05663
# Epoch 22: val loss=0.05608
# Epoch 23: val loss=0.05696
# Epoch 24: val loss=0.05627
# Epoch 25: val loss=0.05698
# Epoch 26: val loss=0.05602
# Epoch 27: val loss=0.05690
# Epoch 28: val loss=0.05669
# Epoch 29: val loss=0.05659
# ...

# %%
# 25 call experiment on CfC

print("Training CFC")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc", best_save="best_cfc_relu.pt")
# Out:
# Training CFC
# Epoch 0: val loss=0.06774
# Epoch 1: val loss=0.06012
# Epoch 2: val loss=0.05672
# Epoch 3: val loss=0.05594
# Epoch 4: val loss=0.05721
# Epoch 5: val loss=0.05626
# Epoch 6: val loss=0.05689
# Epoch 7: val loss=0.05610
# Epoch 8: val loss=0.05545
# Epoch 9: val loss=0.05345
# Epoch 10: val loss=0.05665
# Epoch 11: val loss=0.05501
# Epoch 12: val loss=0.05356
# Epoch 13: val loss=0.05557
# Epoch 14: val loss=0.05354
# Epoch 15: val loss=0.05516
# Epoch 16: val loss=0.05494
# Epoch 17: val loss=0.05440
# Epoch 18: val loss=0.05454
# Epoch 19: val loss=0.05370
# Epoch 20: val loss=0.05395
# Epoch 21: val loss=0.05396
# Epoch 22: val loss=0.05412
# Epoch 23: val loss=0.05326
# Epoch 24: val loss=0.05344
# Epoch 25: val loss=0.05378
# Epoch 26: val loss=0.05278
# Epoch 27: val loss=0.05355
# Epoch 28: val loss=0.05328
# Epoch 29: val loss=0.05440
# ...

# %%
# CFC experiment with much faster time constant

print("Training CFC")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc", best_save="best_cfc_dt3_flat.pt", dt=3.0)
# Out:
# Training CFC
# Epoch 0: val loss=0.05900
# Epoch 1: val loss=0.05998
# Epoch 2: val loss=0.05874
# Epoch 3: val loss=0.05738
# Epoch 4: val loss=0.05770
# Epoch 5: val loss=0.05633
# Epoch 6: val loss=0.05471
# Epoch 7: val loss=0.05654
# Epoch 8: val loss=0.05557
# Epoch 9: val loss=0.05522
# Epoch 10: val loss=0.05446
# Epoch 11: val loss=0.05480
# Epoch 12: val loss=0.05395
# Epoch 13: val loss=0.05509
# Epoch 14: val loss=0.05401
# Epoch 15: val loss=0.05558
# Epoch 16: val loss=0.05495
# Epoch 17: val loss=0.05476
# Epoch 18: val loss=0.05600
# Epoch 19: val loss=0.05601
# Epoch 20: val loss=0.05371
# Epoch 21: val loss=0.05370
# Epoch 22: val loss=0.05386
# Epoch 23: val loss=0.05502
# Epoch 24: val loss=0.05289
# Epoch 25: val loss=0.05461
# Epoch 26: val loss=0.05352
# Epoch 27: val loss=0.05278
# Epoch 28: val loss=0.05251
# Epoch 29: val loss=0.05381
# ...

# %%
# CFC experiment with much slower time constant

print("Training CFC")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc", best_save="best_cfc_dt02_flat.pt", dt=0.2)
# note a run time of 12m 17s, which is much faster than old method
# Out:
# Training CFC
# Epoch 0: val loss=0.06092
# Epoch 1: val loss=0.05901
# Epoch 2: val loss=0.05795
# Epoch 3: val loss=0.05680
# Epoch 4: val loss=0.05579
# Epoch 5: val loss=0.06125
# Epoch 6: val loss=0.05663
# Epoch 7: val loss=0.05716
# Epoch 8: val loss=0.05743
# Epoch 9: val loss=0.05461
# Epoch 10: val loss=0.05612
# Epoch 11: val loss=0.05856
# Epoch 12: val loss=0.05535
# Epoch 13: val loss=0.05475
# Epoch 14: val loss=0.05413
# Epoch 15: val loss=0.05483
# Epoch 16: val loss=0.05457
# Epoch 17: val loss=0.05396
# Epoch 18: val loss=0.05352
# Epoch 19: val loss=0.05495
# Epoch 20: val loss=0.05568
# Epoch 21: val loss=0.05453
# Epoch 22: val loss=0.05617
# Epoch 23: val loss=0.06022
# Epoch 24: val loss=0.05344
# Epoch 25: val loss=0.05746
# Epoch 26: val loss=0.05412
# Epoch 27: val loss=0.05364
# Epoch 28: val loss=0.05747
# Epoch 29: val loss=0.05323
# ...

# %%
# CfC experiment with changed internal architecture
print("Training CfC Type 2")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc2", dt=1.0, best_save="best_cfc_arch2_flat.pt")
# noting here that these are indeed the lowest validation loss scores we have ever seen, yet not the lowest RMSE.
# since we evaluate by MSE in the end, maybe I need to make the loss more similar to the more robust RMSE

# noting a local compile time of 130min 28.6s
# Out:
# Training CfC Type 2
# Epoch 0: val loss=0.05642
# Epoch 1: val loss=0.05544
# Epoch 2: val loss=0.05376
# Epoch 3: val loss=0.05395
# Epoch 4: val loss=0.05302
# Epoch 5: val loss=0.05242
# Epoch 6: val loss=0.05237
# Epoch 7: val loss=0.05226
# Epoch 8: val loss=0.05290
# Epoch 9: val loss=0.05210
# Epoch 10: val loss=0.05208
# Epoch 11: val loss=0.05123
# Epoch 12: val loss=0.05279
# Epoch 13: val loss=0.05214
# Epoch 14: val loss=0.05156
# Epoch 15: val loss=0.05131
# Epoch 16: val loss=0.05199
# Epoch 17: val loss=0.05115
# Epoch 18: val loss=0.05208
# Epoch 19: val loss=0.05090
# Epoch 20: val loss=0.05349
# Epoch 21: val loss=0.05200
# Epoch 22: val loss=0.05147
# Epoch 23: val loss=0.05261
# Epoch 24: val loss=0.05154
# Epoch 25: val loss=0.05113
# Epoch 26: val loss=0.05102
# Epoch 27: val loss=0.05113
# Epoch 28: val loss=0.05082
# Epoch 29: val loss=0.05221
# ...

# %%
# CfC experiment with changed internal architecture, straight from the CfC github
print("Training CfC Type 3")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc3", dt=1.0, best_save="best_cfc_arch3_flat.pt")
# noting here an 84m 26.8s local train time
# Out:
# Training CfC Type 3
# Epoch 0: val loss=0.06338
# Epoch 1: val loss=0.06369
# Epoch 2: val loss=0.05760
# Epoch 3: val loss=0.05969
# Epoch 4: val loss=0.06125
# Epoch 5: val loss=0.06218
# Epoch 6: val loss=0.05902
# Epoch 7: val loss=0.06478
# Epoch 8: val loss=0.06133
# Epoch 9: val loss=0.05733
# Epoch 10: val loss=0.05845
# Epoch 11: val loss=0.06117
# Epoch 12: val loss=0.05527
# Epoch 13: val loss=0.06050
# Epoch 14: val loss=0.05658
# Epoch 15: val loss=0.05547
# Epoch 16: val loss=0.05527
# Epoch 17: val loss=0.05652
# Epoch 18: val loss=0.05898
# Epoch 19: val loss=0.05966
# Epoch 20: val loss=0.06017
# Epoch 21: val loss=0.05755
# Epoch 22: val loss=0.05835
# Epoch 23: val loss=0.06112
# Epoch 24: val loss=0.06087
# Epoch 25: val loss=0.05687
# Epoch 26: val loss=0.05961
# Epoch 27: val loss=0.05913
# Epoch 28: val loss=0.05607
# Epoch 29: val loss=0.05953
# ...

# %%
# run experiment on LTC

print("Training LTC")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="ltc", best_save="best_ltc_optim_flat.pt")
#the new flattened setup makes it so we can train fast enough to train ltc locally
# Out:
# Training LTC
# Epoch 0: val loss=0.05928
# Epoch 1: val loss=0.05670
# Epoch 2: val loss=0.05589
# Epoch 3: val loss=0.05545
# Epoch 4: val loss=0.05573
# Epoch 5: val loss=0.05245
# Epoch 6: val loss=0.05266
# Epoch 7: val loss=0.05276
# Epoch 8: val loss=0.05246
# Epoch 9: val loss=0.05289
# Epoch 10: val loss=0.05211
# Epoch 11: val loss=0.05382
# Epoch 12: val loss=0.05220
# Epoch 13: val loss=0.05287
# Epoch 14: val loss=0.05272
# Epoch 15: val loss=0.05189
# Epoch 16: val loss=0.05199
# Epoch 17: val loss=0.05148
# Epoch 18: val loss=0.05297
# Epoch 19: val loss=0.05173
# Epoch 20: val loss=0.05130
# Epoch 21: val loss=0.05152
# Epoch 22: val loss=0.05138
# Epoch 23: val loss=0.05109
# Epoch 24: val loss=0.05104
# Epoch 25: val loss=0.05171
# Epoch 26: val loss=0.05089
# Epoch 27: val loss=0.05129
# Epoch 28: val loss=0.05145
# Epoch 29: val loss=0.05216
# ...

# %%
#this and next couple cells exist for quickly testing model stuff without re-running training

test_ds = ICUDataset(test_seqs)
test_loader = DataLoader(test_ds, batch_size=64, collate_fn=collate_fn)

model_type = 'gru'
model = GRUModel()
best_save = "best_gru.pt"
model.load_state_dict(torch.load(best_save))
model.to("cuda")

print("1-step RMSE:", rollout_rmse(model, test_loader, 1, model_type))
print("3-step RMSE:", rollout_rmse(model, test_loader, 3, model_type))
print("5-step RMSE:", rollout_rmse(model, test_loader, 5, model_type))
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_23796\2889994020.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_save))
# ...

# %%
model_type = 'lstm'
model = LSTMModel()
best_save = "best_lstm.pt"
model.load_state_dict(torch.load(best_save))
model.to("cuda")

print("1-step RMSE:", rollout_rmse(model, test_loader, 1, model_type))
print("3-step RMSE:", rollout_rmse(model, test_loader, 3, model_type))
print("5-step RMSE:", rollout_rmse(model, test_loader, 5, model_type))
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_19052\338551677.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_save))
# ...

# %%
test_ds = ICUDataset(test_seqs)
test_loader = DataLoader(test_ds, batch_size=64, collate_fn=collate_fn)

model_type = 'cfc'
model = CfCNetwork()
best_save = "best_cfc_relu.pt"
model.load_state_dict(torch.load(best_save))
model.to("cuda")

print("1-step RMSE:", rollout_rmse(model, test_loader, 1, model_type))
print("3-step RMSE:", rollout_rmse(model, test_loader, 3, model_type))
print("5-step RMSE:", rollout_rmse(model, test_loader, 5, model_type))
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_23796\3827873688.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_save))
# ...

# %%
model_type = 'cfc2'
model = CfCNetwork2()
best_save = "best_cfc_arch2.pt"
model.load_state_dict(torch.load(best_save))
model.to("cuda")

print("1-step RMSE:", rollout_rmse(model, test_loader, 1, model_type))
print("3-step RMSE:", rollout_rmse(model, test_loader, 3, model_type))
print("5-step RMSE:", rollout_rmse(model, test_loader, 5, model_type))
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_19052\3521285814.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_save))
# ...

# %%
#test_ds = ICUDataset(test_seqs)
#test_loader = DataLoader(test_ds, batch_size=64, collate_fn=collate_fn)

model_type = 'ltc'
model = LTCNetwork(input_size=21, hidden_size=128, output_size=18, 
                   num_layers=2, solver='euler', ode_unfolds=6)
best_save = "best_ltc.pt"
model.load_state_dict(torch.load(best_save))
model.to("cuda")

print("1-step RMSE:", rollout_rmse(model, test_loader, 1, model_type))
print("3-step RMSE:", rollout_rmse(model, test_loader, 3, model_type))
print("5-step RMSE:", rollout_rmse(model, test_loader, 5, model_type))
#Below scores are obviously poor, but they come from a 1-epoch training run, so that is expected

# %%
# rollout for prediction

# now we must implement a feedback of true data as we rollout predictions
# essentially we will have a prediction forward window, lets say 10 timesteps,
# so we will be predicting forward the next 10 timesteps, but as our window which we use to continue rolling out
# predictions slides forward, we replace our data on the backside of the prediction window
# with real data. Essentially, if our overall window is 100 long, the last 10 of these are all of the current speculation
# that we are doing. The first 90 are all real data. After we make one more prediction, then normally the last 11 are now 
# speculative and only the first 89 are real data. What we will do is replace item number 90 with real data, that way the first 90
# are all real again, and onlt the last 10 are speculative again. This will keep our predictions more on track,
# and this will be more accurate to actual deployment scenario.
def rollout_model(model, df, feature_cols, action_cols,
                  icu_id, model_type, window_size, scaler=None, device="cuda"):
    
    model.eval()
    model.to(device)

    # Extract ICU stay
    g = df[df["ICUSTAY_ID"] == icu_id].sort_values("bin")

    s_true = g[feature_cols].values
    a = g[action_cols].values #don't need to be scaled
    p_window = window_size #prediction window size

    # Scale if needed
    if scaler is not None:
        combined = g[feature_cols].values
        scaled = scaler.transform(combined)
        s_true = scaled[:, :len(feature_cols)]
        #a = scaled[:, len(feature_cols):]

    s_true = torch.tensor(s_true, dtype=torch.float32).to(device)
    a = torch.tensor(a, dtype=torch.float32).to(device)

    cur = s_true[:int(len(s_true)/2)] # initial state using the first half of the sequence, rollout from there
    act = a[:int(len(s_true)/2)]
    #cur = s_true[0].unsqueeze(0)  # initial state
    preds = []

    zero_dif = 346-len(cur)
    zero_growth = 0
    pad = torch.zeros(zero_dif, 18, device=device)
    cur = torch.cat([cur, pad], dim=0)
    pad = torch.zeros(zero_dif, 3, device=device)
    act = torch.cat([act, pad], dim=0)
    cur = cur.unsqueeze(0)
    act = act.unsqueeze(0)

    with torch.no_grad():
        unsqueezed = False
        for t in range(int(len(s_true)/2), int(len(s_true))):
            #here we need to pad cur so the flatten type model can receive it
            if model_type != "GRU" and model_type != "LSTM":
                if unsqueezed:
                    cur = cur.squeeze(0)
                x = torch.cat([cur, act], dim=-1) 
                #x = x.unsqueeze(0)
                #unsqueezed = True
                pred = model(x)
                pred = pred.squeeze(0)
            else:
                pred = model(cur, act)
            preds.append(pred.squeeze(0).cpu().numpy())
            #cur = torch.cat((cur, pred.unsqueeze(0)), dim=0)
            #cur = pred
            if zero_dif > 0:
                cur[0,-zero_dif] = pred
                act[0,-zero_dif] = a[t].unsqueeze(0)
                zero_dif -= 1
                zero_growth += 1

            else:
                #if the input aka cur is already filled and has no more zero fill, then we need to start
                #removing the first step in cur and then append on the latest pred
                pred = pred.unsqueeze(0)
                cur = torch.cat([cur, pred], dim=1)
                cur  = cur[:, 1:]
                act = torch.cat((act[:,1:], (a[t].unsqueeze(0)).unsqueeze(0)), dim=1)
            # then we update the cur values from start up through the timestep right before the
            # start of the prediction window to equal the original data from s_true.
            # cur has already shifted by 1 at this point, so we can go from the start of cur up through the p_window.
            # End of sequence is same end value as original end location, + t so that it moves over time, + 1 because
            # it needs to shift to match the prediction, which is also 1 forward.
            # Start of sequence needs to be simply shifted by the same + 1 and + t
            cur[:,:-p_window-zero_dif] = s_true[t-zero_growth-int(len(s_true)/2)+1:t+1-p_window]

    preds = np.array(preds)
    true = s_true.cpu().numpy()

    # Inverse transform if scaled
    if scaler is not None:
        # reconstruct full row to inverse properly
        dummy = np.zeros((len(preds), len(feature_cols) + len(action_cols)))
        dummy[:, :len(feature_cols)] = preds
        preds = scaler.inverse_transform(dummy[:, :len(feature_cols)])

        dummy[:, :len(feature_cols)] = true[int(len(s_true)/2):int(len(s_true))]
        true = scaler.inverse_transform(dummy[:, :len(feature_cols)])

    # interested in seeing the cumulative error so I can compare that across models as well
    errs = []
    for tru, pred in zip(true, preds):
        err = (pred - tru) ** 2
        errs.append(err)
    err = np.mean(errs)

    return true, preds, err

# %%
# plot prediction function

import matplotlib.pyplot as plt

def plot_predictions(true, preds, feature_cols, features_to_plot):
    T = true.shape[0]
    t = np.arange(T)

    for feat in features_to_plot:
        idx = feature_cols.index(feat)

        plt.figure()
        plt.plot(t, true[:, idx], label="True")
        plt.plot(t, preds[:, idx], label="Predicted")
        plt.title(f"{feat} — Rollout")
        plt.xlabel("Time Step")
        plt.ylabel(feat)
        plt.legend()
        plt.show()

# %%
# compare models on the same ICU stay

def compare_models(models_dict, df, icu_id,
                   feature_cols, action_cols,
                   features_to_plot, window_size,
                   scaler=None,
                   device="cuda"):

    results = {}

    for name, model in models_dict.items():
        true, preds, err = rollout_model(
            model, df,
            feature_cols, action_cols,
            icu_id,
            name,
            window_size=window_size,
            scaler=scaler,
            device=device
        )
        results[name] = preds
        print("Model: " + name + " Average Error: " + str(err))

    T = true.shape[0]
    t = np.arange(T)

    for feat in features_to_plot:
        idx = feature_cols.index(feat)

        plt.figure()
        plt.plot(t, true[:, idx], label="True", linewidth=3)

        for name, preds in results.items():
            plt.plot(t, preds[:, idx], label=name)

        plt.title(f"{feat} — Model Comparison")
        plt.xlabel("Time Step")
        plt.ylabel(feat)
        plt.legend()
        plt.show()

        #attempting to get a closer image of the big long plot
        '''if len(true) > 300:
            plt.figure()
            plt.plot(t, true[50:100, idx], label="True", linewidth=3)

            for name, preds in results.items():
                plt.plot(t, preds[50:100, idx], label=name)

            plt.title(f"{feat} — Model Comparison")
            plt.xlabel("Time Step")
            plt.ylabel(feat)
            plt.legend()
            plt.show()'''

# %%
# subject splitting

def make_subject_splits(full_df,
                        subject_col="SUBJECT_ID",
                        train_frac=0.7, val_frac=0.15, test_frac=0.15,
                        random_state=42):

    unique_subjects = full_df[subject_col].unique()

    train_subj, temp_subj = train_test_split(
        unique_subjects,
        test_size=(1 - train_frac),
        random_state=random_state,
        shuffle=True,
        
    )

    val_size_adjusted = test_frac / (val_frac + test_frac)

    val_subj, test_subj = train_test_split(
        temp_subj,
        test_size=val_size_adjusted,
        random_state=random_state,
        shuffle=True
    )

    return train_subj, val_subj, test_subj

def subjects_to_icu_ids(full_df, subject_ids):
    return full_df[full_df["SUBJECT_ID"].isin(subject_ids)]["ICUSTAY_ID"].unique()

# %%
# prediction and plot run

gru_model = GRUModel()
lstm_model = LSTMModel()
cfc_model = CfCNetwork()
cfc_arch2_model = CfCNetwork2()
cfc_model_3 = CfCNetwork(dt=3.0)
cfc_model_02 = CfCNetwork(dt=0.2)
cfc_arch3_model = CfCNetwork3()
ltc_model = LTCNetwork()
ltc_model_optim = OptimizedLTCNetwork(solver="rk4")
lrc_model = LRCNetwork(cell_type="advanced")
lrc_model_optim = OptimizedLRCNetwork(cell_type="advanced")

gru_model.load_state_dict(torch.load("best_gru.pt"))
#gru_model_original.load_state_dict(torch.load("best_gru_original.pt"))
lstm_model.load_state_dict(torch.load("best_lstm.pt"))
#lstm_model_original.load_state_dict(torch.load("best_lstm_original.pt"))
#cfc_model.load_state_dict(torch.load("best_cfc_flat.pt"))
#cfc_arch2_model.load_state_dict(torch.load("best_cfc_arch2_flat.pt"))
#cfc_arch3_model.load_state_dict(torch.load("best_cfc_arch3_flat.pt"))
#cfc_model_3.load_state_dict(torch.load("best_cfc_dt3_flat.pt"))
#cfc_model_02.load_state_dict(torch.load("best_cfc_dt02_flat.pt"))
#ltc_model.load_state_dict(torch.load("best_ltc.pt"))
#ltc_model_optim.load_state_dict(torch.load("best_ltc_optim_flat.pt"))
#lrc_model.load_state_dict(torch.load("best_lrc.pt"))
#lrc_model_optim.load_state_dict(torch.load("best_lrc_optim.pt"))
models = {
    #"CFC": cfc_model,
    "GRU": gru_model,
    "LSTM": lstm_model,
    #"GRU Original": gru_model_original,
    #"LSTM Original": lstm_model_original,
    #"CFC Arch 2": cfc_arch2_model,
    #"CFC dt=3.0": cfc_model_3,
    #"CFC dt=0.2": cfc_model_02,
    #"CFC Arch 3": cfc_arch3_model,
    #"LTC": ltc_model,
    #"LTC Optimized RK4": ltc_model_optim,
    #"LRC": lrc_model,
    #"LRC Optim": lrc_model_optim
}

features_to_plot = ["heart_rate", "spo2", "dbp", "temperature", "resp_rate", "creatinine",  "platelets"]


train_subj, val_subj, test_subj = make_subject_splits(full_df)

train_icu_ids = subjects_to_icu_ids(full_df, train_subj)
val_icu_ids   = subjects_to_icu_ids(full_df, val_subj)
test_icu_ids  = subjects_to_icu_ids(full_df, test_subj)

# longest ICU stays are 8691, 8980, 8570, 8606, 8612, 8563, 7486, 4199, 3405
compare_models(
    models,
    full_df,
    icu_id=test_icu_ids[8691],
    feature_cols=state_features,
    action_cols=action_features,
    features_to_plot=features_to_plot,
    window_size = 4,
    scaler=scaler,
    device="cuda"
)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_20948\1093165465.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   gru_model.load_state_dict(torch.load("best_gru.pt"))
# ...

# %%
# this is to inform us of which icu stays in the test set are longest

top_longest = [0] * 10
top_icu_ids = [0] * 10
top_lengths = [0] * 10
top_lengths[9] = 1000
for i in range(len(test_icu_ids)):
    icu_id = test_icu_ids[i]
    g = full_df[full_df["ICUSTAY_ID"] == icu_id].sort_values("bin")
    s_true = g[feature_cols].values
    s_length = s_true.shape[0]
    for j in range(len(top_lengths)-1):
        if s_length > top_lengths[j] and s_length < top_lengths[j+1]:
            top_lengths[j] = s_length
            top_longest[j] = i
            top_icu_ids[j] = icu_id
            break
print(top_longest)
print(top_lengths)
print(top_icu_ids)
# Out:
# [8691, 8980, 8570, 8606, 8612, 8563, 7486, 4199, 3405, 0]
# [153, 173, 177, 195, 234, 265, 285, 297, 302, 1000]
# [295542, 298740, 294227, 294579, 294686, 294149, 281683, 245841, 236391, 0]

# %%
# secondary plot run

# the scale of this error value is not the point, the point is the relative value
compare_models(
    models,
    full_df,
    icu_id=test_icu_ids[6231],
    feature_cols=state_features,
    action_cols=action_features,
    features_to_plot=features_to_plot,
    window_size = 4,
    scaler=scaler,
    device="cuda"
)
# Out:
# Model: CFC Average Error: 33320.150120793674
# Model: GRU Average Error: 33288.40508206382
# Model: LSTM Average Error: 30584.713158078685
# Model: CFC Arch 2 Average Error: 33944.39148199687
# Model: CFC dt=3.0 Average Error: 26970.348994025386
# Model: CFC dt=0.2 Average Error: 54125.174811704186
# Model: CFC Arch 3 Average Error: 34579.942115514015
# Model: LTC Optimized RK4 Average Error: 35360.10275300082

# %%
# imports
import tkinter as tk
from tkinter import ttk, scrolledtext
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# set parameters for the bounds for our different health features
SAFE_RANGES = {
    "heart_rate": (40, 180),
    "sbp": (80, 180),
    "dbp": (40, 110),
    "resp_rate": (10, 30),
    "spo2": (90, 100),
    "temperature": (97.0, 99.5),
    "gcs": (3, 15),
    "fio2": (0.21, 1.0),
    "o2_flow": (0, 60),
    "wbc": (4, 12),
    "platelets": (100, 450),
    "creatinine": (0.5, 1.4),
    "bilirubin": (0.1, 2.0),
    "lactate": (0.5, 2.5),
    "inr": (0.8, 2.0),
    "ph": (7.30, 7.45),
    "pco2": (35, 55),
    "po2": (60, 120),
}

# use the rollout graphing code here, modified so it can display graph inside application
def rollout_model_for_gui(
    model,
    df,
    icustay_id,
    feature_cols,
    action_cols,
    model_type,
    window_size,
    scaler=None,
    device="cuda",
):
    model.eval()
    model.to(device)

    # Extract ICU stay
    g = df[df["ICUSTAY_ID"] == icustay_id].sort_values("bin")

    s_true = g[feature_cols].values
    a = g[action_cols].values #don't need to be scaled
    p_window = window_size #prediction window size

    # Scale if needed
    if scaler is not None:
        combined = g[feature_cols].values
        scaled = scaler.transform(combined)
        s_true = scaled[:, :len(feature_cols)]

    s_true = torch.tensor(s_true, dtype=torch.float32).to(device)
    a = torch.tensor(a, dtype=torch.float32).to(device)

    cur = s_true[:int(len(s_true)/2)] # initial state using the first half of the sequence, rollout from there
    act = a[:int(len(s_true)/2)]
    preds = []

    zero_dif = 346-len(cur)
    zero_growth = 0
    pad = torch.zeros(zero_dif, 18, device=device)
    cur = torch.cat([cur, pad], dim=0)
    pad = torch.zeros(zero_dif, 3, device=device)
    act = torch.cat([act, pad], dim=0)
    cur = cur.unsqueeze(0)
    act = act.unsqueeze(0)

    with torch.no_grad():
        unsqueezed = False
        for t in range(int(len(s_true)/2), len(s_true)):
            if model_type != "GRU" and model_type != "LSTM":
                if unsqueezed:
                    cur = cur.squeeze(0)
                x = torch.cat([cur, act], dim=-1) 
                pred = model(x)
                pred = pred.squeeze(0)
            else:
                pred = model(cur, act)
            preds.append(pred[-1].squeeze(0).cpu().numpy())
            if zero_dif > 0:
                cur[0,-zero_dif] = pred
                act[0,-zero_dif] = a[t].unsqueeze(0)
                zero_dif -= 1
                zero_growth += 1

            else:
                pred = pred.unsqueeze(0)
                cur = torch.cat([cur, pred], dim=1)
                cur  = cur[:, 1:]
                act = torch.cat((act[:,1:], (a[t].unsqueeze(0)).unsqueeze(0)), dim=1)
            cur[:,:-p_window-zero_dif] = s_true[t-zero_growth-int(len(s_true)/2)+1:t+1-p_window]
    
    preds = np.array(preds)
    true = s_true.cpu().numpy()

    # Inverse transform if scaled
    if scaler is not None:
        # reconstruct full row to inverse properly
        dummy = np.zeros((len(preds), len(feature_cols) + len(action_cols)))
        dummy[:, :len(feature_cols)] = preds
        preds = scaler.inverse_transform(dummy[:, :len(feature_cols)])

        dummy[:, :len(feature_cols)] = true[int(len(s_true)/2):]
        true = scaler.inverse_transform(dummy[:, :len(feature_cols)])

    times = g["bin"].to_numpy()[int(len(s_true)/2):]

    return times, true, preds

# have text box that flags any time/instance that a feature goes out of range
def generate_alerts(values, times, feature_cols, safe_ranges, label):
    alerts = []

    for t_idx, t in enumerate(times):
        for f_idx, feat in enumerate(feature_cols):
            if feat not in safe_ranges:
                continue

            lo, hi = safe_ranges[feat]
            val = values[t_idx, f_idx]

            if val < lo:
                alerts.append(
                    f"{label}: bin {t} | {feat} LOW | value={val:.3f} | safe=({lo}, {hi})"
                )
            elif val > hi:
                alerts.append(
                    f"{label}: bin {t} | {feat} HIGH | value={val:.3f} | safe=({lo}, {hi})"
                )

    return alerts

# setup GUI
class ICUModelApp:
    def __init__(
        self,
        root,
        full_df,
        models,
        state_cols,
        action_cols,
        scaler=None,
        device="cuda",
    ):
        self.root = root
        self.full_df = full_df
        self.models = models
        self.state_cols = state_cols
        self.action_cols = action_cols
        self.scaler = scaler
        self.device = device

        self.cached_times = None
        self.cached_true = None
        self.cached_model_predictions = None
        self.cached_icu_id = None

        self.root.title("ICU Patient Rollout Monitor")
        self.root.geometry("1500x900")

        self.icu_ids = sorted(full_df["ICUSTAY_ID"].dropna().unique())

        self.build_gui()

    def build_gui(self):
        control_frame = ttk.Frame(self.root)
        control_frame.pack(side=tk.TOP, fill=tk.X, padx=10, pady=10)

        ttk.Label(control_frame, text="ICU Stay:").pack(side=tk.LEFT)

        self.icu_var = tk.StringVar()
        self.icu_dropdown = ttk.Combobox(
            control_frame,
            textvariable=self.icu_var,
            values=[str(int(x)) for x in self.icu_ids],
            width=20,
        )
        self.icu_dropdown.pack(side=tk.LEFT, padx=5)
        self.icu_dropdown.current(0)

        ttk.Label(control_frame, text="Feature:").pack(side=tk.LEFT, padx=(20, 0))

        self.feature_var = tk.StringVar()
        self.feature_dropdown = ttk.Combobox(
            control_frame,
            textvariable=self.feature_var,
            values=self.state_cols,
            width=20,
        )
        self.feature_dropdown.pack(side=tk.LEFT, padx=5)
        self.feature_dropdown.current(0)
        self.feature_dropdown.bind("<<ComboboxSelected>>", self.redraw_cached_plot)

        run_button = ttk.Button(
            control_frame,
            text="Run Rollout",
            command=self.run_rollout,
        )
        run_button.pack(side=tk.LEFT, padx=20)

        main_frame = ttk.Frame(self.root)
        main_frame.pack(fill=tk.BOTH, expand=True)

        plot_frame = ttk.Frame(main_frame)
        plot_frame.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        self.fig, self.ax = plt.subplots(figsize=(9, 6))
        self.canvas = FigureCanvasTkAgg(self.fig, master=plot_frame)
        self.canvas.get_tk_widget().pack(fill=tk.BOTH, expand=True)

        alert_frame = ttk.Frame(main_frame)
        alert_frame.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True)

        ttk.Label(alert_frame, text="Predicted Out-of-Range Alerts").pack()
        self.pred_alert_box = scrolledtext.ScrolledText(alert_frame, width=70, height=20)
        self.pred_alert_box.pack(fill=tk.BOTH, expand=True, padx=5, pady=5)

        ttk.Label(alert_frame, text="True Data Out-of-Range Alerts").pack()
        self.true_alert_box = scrolledtext.ScrolledText(alert_frame, width=70, height=20)
        self.true_alert_box.pack(fill=tk.BOTH, expand=True, padx=5, pady=5)

    def run_rollout(self):
        icu_id = float(self.icu_var.get())
        self.ax.clear()

        all_true = None
        all_times = None
        model_predictions = {}

        for model_name, model in self.models.items():
            times, true, preds = rollout_model_for_gui(
                model=model,
                df=self.full_df,
                icustay_id=icu_id,
                feature_cols=self.state_cols,
                action_cols=self.action_cols,
                model_type=model_name,
                window_size=2,
                scaler=self.scaler,
                device=self.device,
            )

            all_true = true
            all_times = times
            model_predictions[model_name] = preds
            
        self.cached_times = all_times
        self.cached_true = all_true
        self.cached_model_predictions = model_predictions
        self.cached_icu_id = icu_id

        self.redraw_cached_plot()
        self.update_alerts()

    def redraw_cached_plot(self, event=None):
        if self.cached_times is None:
            return

        feature = self.feature_var.get()
        feat_idx = self.state_cols.index(feature)

        self.ax.clear()

        for model_name, preds in self.cached_model_predictions.items():
            self.ax.plot(
                self.cached_times,
                preds[:, feat_idx],
                label=f"{model_name} predicted"
            )

        self.ax.plot(
            self.cached_times,
            self.cached_true[:, feat_idx],
            label="True",
            linewidth=3,
        )

        if feature in SAFE_RANGES:
            lo, hi = SAFE_RANGES[feature]
            self.ax.axhline(lo, linestyle="--", label="Lower safe bound")
            self.ax.axhline(hi, linestyle="--", label="Upper safe bound")

        self.ax.set_title(f"ICU Stay {int(self.cached_icu_id)} — {feature}")
        self.ax.set_xlabel("12-hour bin")
        self.ax.set_ylabel(feature)
        self.ax.legend()
        self.canvas.draw()
        self.update_alerts()

    def update_alerts(self):
        if self.cached_times is None:
            return

        feature = self.feature_var.get()
        feat_idx = self.state_cols.index(feature)

        self.pred_alert_box.delete("1.0", tk.END)
        self.true_alert_box.delete("1.0", tk.END)

        if feature not in SAFE_RANGES:
            self.pred_alert_box.insert(tk.END, "No safe range configured.")
            self.true_alert_box.insert(tk.END, "No safe range configured.")
            return

        lo, hi = SAFE_RANGES[feature]

        # true alerts
        true_alerts = []
        for t_idx, t in enumerate(self.cached_times):
            val = self.cached_true[t_idx, feat_idx]

            if val < lo:
                true_alerts.append(
                    f"bin {t} | LOW | value={val:.3f} | safe=({lo}, {hi})"
                )

            elif val > hi:
                true_alerts.append(
                    f"bin {t} | HIGH | value={val:.3f} | safe=({lo}, {hi})"
                )

        # predicted alerts
        pred_alerts = []
        for model_name, preds in self.cached_model_predictions.items():

            for t_idx, t in enumerate(self.cached_times):

                val = preds[t_idx, feat_idx]

                if val < lo:
                    pred_alerts.append(
                        f"{model_name} | bin {t} | LOW | "
                        f"value={val:.3f} | safe=({lo}, {hi})"
                    )

                elif val > hi:
                    pred_alerts.append(
                        f"{model_name} | bin {t} | HIGH | "
                        f"value={val:.3f} | safe=({lo}, {hi})"
                    )

        # display
        self.pred_alert_box.insert(
            tk.END,
            "\n".join(pred_alerts) if pred_alerts else "No predicted alerts."
        )
        self.true_alert_box.insert(
            tk.END,
            "\n".join(true_alerts) if true_alerts else "No true-data alerts."
        )

# %%
STATE_COLS = [
    "heart_rate", "sbp", "dbp", "resp_rate", "spo2", "temperature",
    "gcs", "fio2", "o2_flow", "wbc", "platelets", "creatinine",
    "bilirubin", "lactate", "inr", "ph", "pco2", "po2"
]

ACTION_COLS = [
    "iv_fluids",
    "vasopressors",
    "antibiotics",
]

models = {
    "GRU": gru_model,
    "LSTM": lstm_model,
    #"CFC": cfc_model,
}

root = tk.Tk()

app = ICUModelApp(
    root=root,
    full_df=full_df,
    models=models,
    state_cols=STATE_COLS,
    action_cols=ACTION_COLS,
    scaler=scaler,
    device="cuda",
)

root.mainloop()
