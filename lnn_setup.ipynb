# %%
# 1 Library setup
import os
import glob
import numpy as np
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge


DATA_DIR = "data/data"
OUT_DIR = "icu_batches"
MERGED_PATH = "icu_merged.parquet"

BIN_HOURS = 12
BATCH_SIZE = 3000

os.makedirs(OUT_DIR, exist_ok=True)

# %%
# 2 Load data and setup metadata

icustays = pd.read_csv(f"{DATA_DIR}/ICUSTAYS.csv")
admissions = pd.read_csv(f"{DATA_DIR}/ADMISSIONS.csv")
patients = pd.read_csv(f"{DATA_DIR}/PATIENTS.csv")

icu_meta = (
    icustays
    .merge(admissions, on=["SUBJECT_ID", "HADM_ID"], how="left")
    .merge(patients, on="SUBJECT_ID", how="left")
)

icu_meta = icu_meta[[
    "SUBJECT_ID",
    "HADM_ID",
    "ICUSTAY_ID",
    "INTIME",
    "OUTTIME"
]]

icu_meta["INTIME"] = pd.to_datetime(icu_meta["INTIME"])
icu_meta["OUTTIME"] = pd.to_datetime(icu_meta["OUTTIME"])


# I am no longer calling this, as we are running into the issue of somehow the icustay_ids with missing 
# out times are also missing from our computed out time results, but the code may prove useful later
def compute_last_event_time():
    last_times = []

    # CHARTEVENTS
    ce = pd.read_csv(
        f"{DATA_DIR}/CHARTEVENTS.csv",
        usecols=["ICUSTAY_ID", "CHARTTIME"]
    )
    ce["CHARTTIME"] = pd.to_datetime(ce["CHARTTIME"])
    last_times.append(
        ce.groupby("ICUSTAY_ID")["CHARTTIME"].max()
    )

    # INPUTEVENTS_MV
    ie = pd.read_csv(
        f"{DATA_DIR}/INPUTEVENTS_MV.csv",
        usecols=["ICUSTAY_ID", "ENDTIME"]
    )
    ie["ENDTIME"] = pd.to_datetime(ie["ENDTIME"])
    last_times.append(
        ie.groupby("ICUSTAY_ID")["ENDTIME"].max()
    )

    # OUTPUTEVENTS
    oe = pd.read_csv(
        f"{DATA_DIR}/OUTPUTEVENTS.csv",
        usecols=["ICUSTAY_ID", "CHARTTIME"]
    )
    oe["CHARTTIME"] = pd.to_datetime(oe["CHARTTIME"])
    last_times.append(
        oe.groupby("ICUSTAY_ID")["CHARTTIME"].max()
    )

    # PRESCRIPTIONS
    pr = pd.read_csv(
        f"{DATA_DIR}/PRESCRIPTIONS.csv",
        usecols=["ICUSTAY_ID", "ENDDATE"]
    )
    pr["ENDDATE"] = pd.to_datetime(pr["ENDDATE"])
    last_times.append(
        pr.groupby("ICUSTAY_ID")["ENDDATE"].max()
    )

    # Combine all
    all_last = pd.concat(last_times, axis=1)
    return all_last.max(axis=1)  # row-wise max


print("Missing outtime:", icu_meta["OUTTIME"].isna().sum())
icu_meta = icu_meta.dropna(subset=["OUTTIME"]).reset_index(drop=True)
assert icu_meta["OUTTIME"].notna().all()
assert (icu_meta["OUTTIME"] > icu_meta["INTIME"]).all()
# Out:
# Missing outtime: 10

# %%
# 3 create structure for bins

def build_base_grid(batch_meta):
    rows = []
    for _, r in batch_meta.iterrows():
        n_bins = int(
            np.ceil(
                (r.OUTTIME - r.INTIME).total_seconds()
                / (BIN_HOURS * 3600)
            )
        )
        for b in range(n_bins):
            rows.append({
                "SUBJECT_ID": r.SUBJECT_ID,
                "ICUSTAY_ID": r.ICUSTAY_ID,
                "bin": b
            })
    return pd.DataFrame(rows)

# %%
# 4 obtain desired vitals info from chartevents

'''VITAL_ITEMIDS = {
    "heart_rate": [211, 220045],
    "mean_bp": [456, 220052],
    "spo2": [646, 220277],
    "resp_rate": [618, 220210],
    "temperature": [223761, 678]
}'''
VITAL_ITEMIDS = {
    # Heart rate
    "heart_rate": [211, 220045],

    # Systolic BP
    "sbp": [51, 442, 455, 6701, 220179],

    # Diastolic BP
    "dbp": [8368, 8440, 8441, 8555, 220180],

    # Respiratory rate
    "resp_rate": [618, 220210],

    # Oxygen saturation
    "spo2": [646, 220277],

    # Temperature (Fahrenheit)
    "temperature": [223761, 678],

    # Glasgow Coma Scale (total)
    "gcs": [198, 226755],

    # FiO2 (fraction, NOT %)
    "fio2": [190, 223835],

    # O2 flow rate
    "o2_flow": [470, 471, 223834],
}
ALL_VITAL_ITEMIDS = sum(VITAL_ITEMIDS.values(), [])

def build_vitals(batch_icustays, icu_meta):
    chunks = pd.read_csv(
        f"{DATA_DIR}/CHARTEVENTS.csv",
        usecols=["SUBJECT_ID", "ICUSTAY_ID", "ITEMID", "CHARTTIME", "VALUENUM"],
        chunksize=5_000_000
    )

    out = []

    for df in chunks:
        df = df[df.ICUSTAY_ID.isin(batch_icustays)]
        df = df[df.ITEMID.isin(ALL_VITAL_ITEMIDS)]

        if df.empty:
            continue

        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        df = df.merge(
            icu_meta[["SUBJECT_ID", "ICUSTAY_ID", "INTIME"]],
            on=["SUBJECT_ID","ICUSTAY_ID"],
            how="left"
        )

        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        df = (
            df.groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin", "ITEMID"])["VALUENUM"]
            .mean()
            .reset_index()
        )

        out.append(df)

    df = pd.concat(out, ignore_index=True)

    # Pivot ITEMIDs → named columns
    features = {}
    for name, ids in VITAL_ITEMIDS.items():
        features[name] = (
            df[df.ITEMID.isin(ids)]
            .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["VALUENUM"]
            .mean()
        )

    vitals = pd.concat(features, axis=1).reset_index()
    return vitals

# %%
# 5 obtain desired lab features from labevents

'''LAB_ITEMIDS = {
    "anion gap": [50868],
    "albumin": [50862],
    "bilirubin": [50885],
    "creatinine": [50912],
    "glucose": [50931],
    "hemoglobin": [51222],
    "lactate": [50813],
    "platelet count": [51265],
    "potassium": [50971],
    "sodium": [50983],
    "wbc": [51516]
}'''
LAB_ITEMIDS = {
    # Hematology
    "wbc": [51301, 51516],
    "platelets": [51265],

    # Renal / liver
    "creatinine": [50912],
    "bilirubin": [50885],

    # Metabolic
    "lactate": [50813],

    # Coagulation
    "inr": [51237],

    # Blood gas / acid–base
    "ph": [50820],
    "pco2": [50818],
    "po2": [50821],
}

ALL_LAB_ITEMIDS = sum(LAB_ITEMIDS.values(), [])

def build_labs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned lab features from LABEVENTS.

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | lab_1 | lab_2 | ...
    """

    chunks = pd.read_csv(
        f"{DATA_DIR}/LABEVENTS.csv",
        usecols=[
            "SUBJECT_ID",
            "HADM_ID",
            "ITEMID",
            "CHARTTIME",
            "VALUENUM"
        ],
        chunksize=2_000_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch stays
        df = df[df.HADM_ID.isin(
            icu_meta[
                icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
            ].HADM_ID.unique()
        )]

        # 2. Filter to labs of interest
        df = df[df.ITEMID.isin(ALL_LAB_ITEMIDS)]

        if df.empty:
            continue

        # 3. Parse time
        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        # 4. Attach ICU INTIME
        df = df.merge(
            icu_meta[["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID", "INTIME"]],
            on=["SUBJECT_ID", "HADM_ID"],
            how="left"
        )

        # Drop labs outside ICU stay
        df = df[
            (df.CHARTTIME >= df.INTIME) &
            (df.CHARTTIME <= icu_meta.set_index("ICUSTAY_ID")
                              .loc[df.ICUSTAY_ID]
                              .OUTTIME.values)
        ]

        # 5. Compute 12h bin
        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        # 6. Aggregate within bin
        df = (
            df.groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin", "ITEMID"])["VALUENUM"]
            .mean()
            .reset_index()
        )

        out.append(df)

    if not out:
        return pd.DataFrame(columns=["SUBJECT_ID", "ICUSTAY_ID", "bin"])

    df = pd.concat(out, ignore_index=True)

    # 7. Pivot ITEMIDs → lab names
    lab_frames = []

    for lab, ids in LAB_ITEMIDS.items():
        tmp = (
            df[df.ITEMID.isin(ids)]
            .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["VALUENUM"]
            .mean()
            .rename(lab)
        )
        lab_frames.append(tmp)

    labs = pd.concat(lab_frames, axis=1).reset_index()

    return labs

# %%
# 6 obtain iv fluid sum and vasopressor sum  from inputevents

FLUID_ITEMIDS = [
    41913, 6190,  # NS
    30021, 2971, 44367, 225828,  # LR
    1848,  # D5W
    3066, 1521, 2358, 40548, 46564, 45403, 227456  # Albumin
]

VASOPRESSOR_ITEMIDS = [
    30120, 221906, 30047,  # norepinephrine
    221289, 30044, 30119,  # epinephrine
    221662, 5329, 30043,  # dopamine
    221749, 5656, 30128,  # phenylephrine
    22315, 1136, 1222 # vasopressin
]

def build_inputs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build action features (iv_fluids, vasopressors) binned into 12-hour windows.
    """

    # 1. Load INPUTEVENTS_MV
    df = pd.read_csv(
        f"{DATA_DIR}/INPUTEVENTS_MV.csv",
        usecols=[
            "SUBJECT_ID", 
            "ICUSTAY_ID",
            "ITEMID",
            "STARTTIME",
            "ENDTIME",
            "AMOUNT",
            "RATE"
        ]
    )

    df = df[df.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)]
    if df.empty:
        return pd.DataFrame(
            columns=["SUBJECT_ID", "ICUSTAY_ID", "bin", "iv_fluids", "vasopressors"]
        )

    df["STARTTIME"] = pd.to_datetime(df["STARTTIME"])
    df["ENDTIME"] = pd.to_datetime(df["ENDTIME"])

    # 2. Attach ICU INTIME
    df = df.merge(
        icu_meta[["SUBJECT_ID", "ICUSTAY_ID", "INTIME"]],
        on=["SUBJECT_ID", "ICUSTAY_ID"],
        how="left"
    )

    # 3. Build bins
    bins = []

    for _, row in icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
    ].iterrows():

        n_bins = int(
            np.ceil(
                (row.OUTTIME - row.INTIME).total_seconds()
                / (BIN_HOURS * 3600)
            )
        )

        for b in range(n_bins):
            bins.append({
                "SUBJECT_ID": row.SUBJECT_ID, 
                "ICUSTAY_ID": row.ICUSTAY_ID,
                "bin": b,
                "bin_start": row.INTIME + pd.Timedelta(hours=b * BIN_HOURS),
                "bin_end": row.INTIME + pd.Timedelta(hours=(b + 1) * BIN_HOURS),
            })

    bins_df = pd.DataFrame(bins)

    # 4. Helper: overlap minutes
    def overlap_minutes(start1, end1, start2, end2):
        start = max(start1, start2)
        end = min(end1, end2)
        return max(0, (end - start).total_seconds() / 60.0)

    # 5. IV FLUIDS (continuous sum)
    iv = df[df.ITEMID.isin(FLUID_ITEMIDS)].copy()
    iv = iv[(iv.STARTTIME.notna()) & (iv.ENDTIME.notna())]

    iv["duration_min"] = (
        iv.ENDTIME - iv.STARTTIME
    ).dt.total_seconds() / 60

    iv["RATE"] = iv["RATE"].fillna(
        iv["AMOUNT"] / iv["duration_min"]
    )

    iv = iv[(iv.RATE.notna()) & (iv.duration_min > 0)]

    iv_values = []

    for _, bin_row in bins_df.iterrows():
        active = iv[
            (iv.ICUSTAY_ID == bin_row.ICUSTAY_ID) &
            (iv.ENDTIME > bin_row.bin_start) &
            (iv.STARTTIME < bin_row.bin_end)
        ]

        total = 0.0
        for _, r in active.iterrows():
            mins = overlap_minutes(
                r.STARTTIME, r.ENDTIME,
                bin_row.bin_start, bin_row.bin_end
            )
            total += mins * r.RATE

        iv_values.append(total)

    bins_df["iv_fluids"] = iv_values

    # 6. VASOPRESSORS (continuous sum)
    vp = df[df.ITEMID.isin(VASOPRESSOR_ITEMIDS)].copy()
    vp = vp[(vp.STARTTIME.notna()) & (vp.ENDTIME.notna())]

    vp["duration_min"] = (
        vp.ENDTIME - vp.STARTTIME
    ).dt.total_seconds() / 60

    vp["RATE"] = vp["RATE"].fillna(
        vp["AMOUNT"] / vp["duration_min"]
    )

    vp = vp[(vp.RATE.notna()) & (vp.duration_min > 0)]

    vp_values = []

    for _, bin_row in bins_df.iterrows():
        active = vp[
            (vp.ICUSTAY_ID == bin_row.ICUSTAY_ID) &
            (vp.ENDTIME > bin_row.bin_start) &
            (vp.STARTTIME < bin_row.bin_end)
        ]

        total = 0.0
        for _, r in active.iterrows():
            mins = overlap_minutes(
                r.STARTTIME, r.ENDTIME,
                bin_row.bin_start, bin_row.bin_end
            )
            total += mins * r.RATE

        vp_values.append(total)

    bins_df["vasopressors"] = vp_values

    # 7. Final output
    return bins_df[[
        "SUBJECT_ID", 
        "ICUSTAY_ID",
        "bin",
        "iv_fluids",
        "vasopressors"
    ]]

# %%
# 7 Backtracked this for now, I don't think Alex actually ended up using OUTPUTEVENTS or INPUTEVENTS_CV

URINE_ITEMIDS = [
    40055,  # Urine Out Foley
    40069,  # Urine Out Void
    40094,  # Urine Out Condom Cath
    40428,  # Urine Out Straight Cath
    40715,  # Urine Out Suprapubic
    40473,  # Urine Out Ileoconduit
]

def build_outputs(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned ICU output features (urine output).

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | urine_output
    """

    chunks = pd.read_csv(
        f"{DATA_DIR}/OUTPUTEVENTS.csv",
        usecols=[
            "ICUSTAY_ID",
            "ITEMID",
            "CHARTTIME",
            "VALUE"
        ],
        chunksize=1_000_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch ICU stays
        df = df[df.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)]
        if df.empty:
            continue

        # 2. Keep urine outputs only
        df = df[df.ITEMID.isin(URINE_ITEMIDS)]
        if df.empty:
            continue

        # 3. Parse time
        df["CHARTTIME"] = pd.to_datetime(df["CHARTTIME"])

        # 4. Attach ICU INTIME
        df = df.merge(
            icu_meta[["ICUSTAY_ID", "INTIME"]],
            on="ICUSTAY_ID",
            how="left"
        )

        # 5. Compute 12-hour bin
        df["bin"] = (
            (df.CHARTTIME - df.INTIME)
            .dt.total_seconds() // (BIN_HOURS * 3600)
        ).astype(int)

        # 6. Aggregate urine output
        urine = (
            df.groupby(["ICUSTAY_ID", "bin"])["VALUE"]
            .sum()
            .rename("urine_output")
        )

        out.append(urine)

    if not out:
        return pd.DataFrame(
            columns=["ICUSTAY_ID", "bin", "urine_output"]
        )

    outputs = pd.concat(out).reset_index()
    return outputs

# %%
# 8 obtain a binary of whether the patient has or hasnt received antibiotics by scanning to see if they
# received any of the common keywords for types of antibiotics

ANTIBIOTIC_KEYWORDS = [
    "cef", "ceph",
    "penicillin", "pip", "tazo",
    "vancomycin", "vanc",
    "levofloxacin", "ciprofloxacin",
    "meropenem", "imipenem",
    "azithromycin", "clarithromycin",
    "gentamicin", "amikacin",
    "clindamycin", "metronidazole",
    "doxycycline", "linezolid"
]

def build_prescriptions(batch_ICUSTAY_IDs, icu_meta):
    """
    Build 12-hour binned prescription features (antibiotic exposure).

    Returns:
        DataFrame with columns:
        ICUSTAY_ID | bin | antibiotics
    """

    # Map ICU stays → admissions
    batch_meta = icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ICUSTAY_IDs)
    ][["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID", "INTIME", "OUTTIME"]]

    HADM_IDs = batch_meta.HADM_ID.unique()

    chunks = pd.read_csv(
        f"{DATA_DIR}/PRESCRIPTIONS.csv",
        usecols=[
            "SUBJECT_ID",
            "HADM_ID",
            "STARTDATE",
            "ENDDATE",
            "DRUG"
        ],
        chunksize=500_000
    )

    out = []

    for df in chunks:
        # 1. Filter to batch admissions
        df = df[df.HADM_ID.isin(HADM_IDs)]
        if df.empty:
            continue

        # 2. Identify antibiotics
        drug_lower = df["DRUG"].str.lower().fillna("")
        is_abx = drug_lower.apply(
            lambda x: any(k in x for k in ANTIBIOTIC_KEYWORDS)
        )
        df = df[is_abx]
        if df.empty:
            continue

        # 3. Parse times
        df["STARTDATE"] = pd.to_datetime(df["STARTDATE"])
        df["ENDDATE"] = pd.to_datetime(df["ENDDATE"])

        # If ENDDATE missing, assume one dose (common)
        df["ENDDATE"] = df["ENDDATE"].fillna(df["STARTDATE"])

        # 4. Attach ICU metadata
        df = df.merge(
            batch_meta,
            on=["SUBJECT_ID", "HADM_ID"],
            how="left"
        )

        # Drop prescriptions outside ICU stay
        df = df[
            (df.ENDDATE >= df.INTIME) &
            (df.STARTDATE <= df.OUTTIME)
        ]

        if df.empty:
            continue

        # 5. Expand prescription duration into bins
        rows = []

        for _, r in df.iterrows():
            start_bin = int(
                max(
                    0,
                    (r.STARTDATE - r.INTIME).total_seconds()
                    // (BIN_HOURS * 3600)
                )
            )
            end_bin = int(
                (r.ENDDATE - r.INTIME).total_seconds()
                // (BIN_HOURS * 3600)
            )

            for b in range(start_bin, end_bin + 1):
                rows.append({
                    "SUBJECT_ID": r.SUBJECT_ID,
                    "ICUSTAY_ID": r.ICUSTAY_ID,
                    "bin": b,
                    "antibiotics": 1
                })

        if rows:
            out.append(pd.DataFrame(rows))

    if not out:
        return pd.DataFrame(
            columns=["SUBJECT_ID", "ICUSTAY_ID", "bin", "antibiotics"]
        )

    # 6. Collapse duplicates
    prescriptions = (
        pd.concat(out, ignore_index=True)
        .groupby(["SUBJECT_ID", "ICUSTAY_ID", "bin"])["antibiotics"]
        .max()
        .reset_index()
    )

    return prescriptions

# %%
# 9 perform batching and binning

icu_ids = np.sort(icu_meta.ICUSTAY_ID.unique())
batches = np.array_split(
    icu_ids,
    int(np.ceil(len(icu_ids) / BATCH_SIZE))
)

for i, batch_ids in enumerate(batches):
    print(f"Batch {i}: {len(batch_ids)} stays")

    batch_meta = icu_meta[
        icu_meta.ICUSTAY_ID.isin(batch_ids)
    ]

    base = build_base_grid(batch_meta)
    vitals = build_vitals(batch_ids, icu_meta)
    labs = build_labs(batch_ids, icu_meta)
    inputs = build_inputs(batch_ids, icu_meta)
    #outputs = build_outputs(batch_ids, icu_meta)
    meds = build_prescriptions(batch_ids, icu_meta)

    df = base
    for feat in [vitals, labs, inputs, meds]:
        df = df.merge(
            feat,
            on=["SUBJECT_ID", "ICUSTAY_ID", "bin"],
            how="left"
        )

    df.to_parquet(
        f"{OUT_DIR}/batch_{i:02d}.parquet",
        index=False
    )
# Out:
# Batch 0: 2930 stays
# Batch 1: 2930 stays
# Batch 2: 2930 stays
# Batch 3: 2930 stays
# Batch 4: 2930 stays
# Batch 5: 2930 stays
# Batch 6: 2930 stays
# Batch 7: 2930 stays
# Batch 8: 2930 stays
# Batch 9: 2930 stays
# Batch 10: 2930 stays
# Batch 11: 2930 stays
# Batch 12: 2930 stays
# Batch 13: 2929 stays
# Batch 14: 2929 stays
# Batch 15: 2929 stays
# Batch 16: 2929 stays
# Batch 17: 2929 stays
# Batch 18: 2929 stays
# Batch 19: 2929 stays
# Batch 20: 2929 stays

# %%
# 10 batch merging

files = glob.glob(f"{OUT_DIR}/batch_*.parquet")

full_df = pd.concat(
    (pd.read_parquet(f) for f in files),
    ignore_index=True
)

# %%
# 11 data cleaning and imputation

phys_cols = list(VITAL_ITEMIDS.keys())

full_df = full_df.sort_values(["ICUSTAY_ID", "bin"])
full_df["antibiotics"] = full_df["antibiotics"].fillna(0)
full_df[phys_cols] = (
    full_df.groupby("ICUSTAY_ID")[phys_cols]
    .ffill()
)

intervention_cols = []  # e.g. vasopressors, antibiotics
full_df[intervention_cols] = full_df[intervention_cols].fillna(0)

numeric_cols = full_df.select_dtypes(include="number").columns

for c in numeric_cols:
    lo = full_df[c].quantile(0.001)
    hi = full_df[c].quantile(0.999)
    full_df[c] = full_df[c].clip(lo, hi)

full_df["heart_rate"] = full_df["heart_rate"].clip(30, 220)
full_df["spo2"] = full_df["spo2"].clip(50, 100)
full_df["sbp"] = full_df["sbp"].clip(50, 180)
full_df["dbp"] = full_df["dbp"].clip(30, 140)

# %%
# 12 iterative Bayesian-Ridge imputation for residual gaps

imputer = IterativeImputer(
    estimator=BayesianRidge(),
    max_iter=10,
    random_state=0
)


full_df[numeric_cols] = imputer.fit_transform(
    full_df[numeric_cols]
)

# %%
# 13 data audit to check validity (no Nan and no Inf), then save

assert full_df.isna().sum().sum() == 0
assert np.isfinite(full_df[numeric_cols]).all().all()

full_df.to_parquet(MERGED_PATH, index=False)

# %%
# 14 load from parquet file (only needs to be run if you don't want to run all the code before this point)

full_df = pd.read_parquet(MERGED_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 3
#       1 # 14 load from parquet file
# ----> 3 full_df = pd.read_parquet(MERE)
#
# NameError: name 'MERE' is not defined

# %%
# 15 group data into sequences by stay

def build_sequences(full_df, state_cols, action_cols, id_col="ICUSTAY_ID", time_col="bin", return_ids=True):

    sequences = []
    ids = []

    # Ensure proper ordering
    df = full_df.sort_values(["SUBJECT_ID", id_col, time_col])

    for (SUBJECT_ID, ICUSTAY_ID), group in df.groupby(["SUBJECT_ID", "ICUSTAY_ID"]):
        group = group.sort_values(time_col)

        states = group[state_cols].to_numpy(dtype=np.float32)
        actions = group[action_cols].to_numpy(dtype=np.float32)

        T = len(group)
        if T < 2:
            continue

        seq = {
            "SUBJECT_ID": SUBJECT_ID,
            "ICUSTAY_ID": ICUSTAY_ID,
            "states": states[:-1],       # (T-1, 18)
            "actions": actions[:-1],     # (T-1, 3)
            "next_states": states[1:],   # (T-1, 18)
            "length": T - 1
        }

        sequences.append(seq)
    return sequences
    
state_features = [
    "heart_rate", "sbp", "dbp", "resp_rate", "spo2", "temperature",
    "gcs", "fio2", "o2_flow", "wbc", "platelets", "creatinine",
    "bilirubin", "lactate", "inr", "ph", "pco2", "po2"
]
action_features = [
    "iv_fluids", "vasopressors", "antibiotics"
]
feature_cols = state_features + action_features

sequences = build_sequences(full_df, state_features, action_features)

# %%
# not using this data split anymore, as I think my second one is more robust
# still leaving it here just in case

def split_sequences_train_val_test(sequences, ids, seed=42):
    assert len(sequences) == len(ids)

    N = len(sequences)
    rng = np.random.default_rng(seed)

    indices = np.arange(N)
    rng.shuffle(indices)

    n_train = int(0.70 * N)
    n_val = int(0.15 * N)

    train_idx = indices[:n_train] # first 70%
    val_idx = indices[n_train:n_train + n_val] # the 15% from 70 to 85% range
    test_idx = indices[n_train + n_val:] # the 15% from 85 to 100% range

    def take(idx):
        return [sequences[i] for i in idx]

    X_train= take(train_idx)
    X_val= take(val_idx)
    X_test= take(test_idx)

    return X_train, X_val, X_test

#X_train, X_val, X_test = split_sequences_train_val_test(sequences)

# %%
# 16 data split
from collections import defaultdict

def split_sequences_by_subject(sequences, seed=42):
    # Collect unique subjects
    subject_to_seqs = defaultdict(list)

    for seq in sequences:
        subject_to_seqs[seq["SUBJECT_ID"]].append(seq)

    subjects = list(subject_to_seqs.keys())

    # Shuffle subjects
    rng = np.random.default_rng(seed)
    rng.shuffle(subjects)

    # Split subjects
    N = len(subjects)
    n_train = int(0.70 * N)
    n_val = int(0.15 * N)

    train_subjects = set(subjects[:n_train]) # first 70%
    val_subjects   = set(subjects[n_train:n_train + n_val]) # the 15% from 70 to 85% range
    test_subjects  = set(subjects[n_train + n_val:]) # the 15% from 85 to 100% range

    # Assign sequences
    train_seqs = []
    val_seqs = []
    test_seqs = []

    for subj, seqs in subject_to_seqs.items():
        if subj in train_subjects:
            train_seqs.extend(seqs)
        elif subj in val_subjects:
            val_seqs.extend(seqs)
        elif subj in test_subjects:
            test_seqs.extend(seqs)
        else:
            raise RuntimeError("Subject not assigned to any split")

    return train_seqs, val_seqs, test_seqs

train_seqs, val_seqs, test_seqs = split_sequences_by_subject(sequences)
print("done")
# Out:
# done

# %%
# 17 scaling data

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
all_train_states = np.concatenate([s["states"] for s in train_seqs], axis=0)
scaler.fit(all_train_states)

def apply_scaler(seqs, scaler):
    out = []
    for s in seqs:
        s2 = dict(s)
        s2["states"] = scaler.transform(s["states"])
        s2["next_states"] = scaler.transform(s["next_states"])
        out.append(s2)
    return out

train_seqs = apply_scaler(train_seqs, scaler)
val_seqs   = apply_scaler(val_seqs, scaler)
test_seqs  = apply_scaler(test_seqs, scaler)

# %%
def check_nan(split, name):
    for i, s in enumerate(split):
        if np.isnan(s["states"]).any():
            print(f"NaN in {name} states seq {i}")
        if np.isnan(s["actions"]).any():
            print(f"NaN in {name} actions seq {i}")
        if np.isnan(s["next_states"]).any():
            print(f"NaN in {name} next_states seq {i}")
        if np.isinf(s["states"]).any():
            print(f"NaN in {name} states seq {i}")
        if np.isinf(s["actions"]).any():
            print(f"NaN in {name} actions seq {i}")
        if np.isinf(s["next_states"]).any():
            print(f"NaN in {name} next_states seq {i}")

check_nan(train_seqs, "train")
check_nan(val_seqs, "val")
check_nan(test_seqs, "test")
assert not np.isnan(all_train_states).any()
assert not np.isinf(all_train_states).any()

# %%
# 18

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

class ICUDataset(Dataset):
    def __init__(self, sequences):
        self.seqs = sequences

    def __len__(self):
        return len(self.seqs)

    def __getitem__(self, idx):
        s = self.seqs[idx]
        return {
            "states": torch.tensor(s["states"], dtype=torch.float32),
            "actions": torch.tensor(s["actions"], dtype=torch.float32),
            "next_states": torch.tensor(s["next_states"], dtype=torch.float32),
            "length": s["length"]
        }


def collate_fn(batch):
    lengths = torch.tensor([b["length"] for b in batch], dtype=torch.long)
    max_len = lengths.max()

    def pad(x):
        out = torch.zeros(len(batch), max_len, x[0].shape[-1])
        for i, b in enumerate(x):
            out[i, :b.shape[0]] = b
        return out

    states = pad([b["states"] for b in batch])
    actions = pad([b["actions"] for b in batch])
    next_states = pad([b["next_states"] for b in batch])

    mask = torch.arange(max_len)[None, :] < lengths[:, None]

    return states, actions, next_states, mask

# %%
# 19 GRU model setup

class GRUModel(nn.Module):
    def __init__(self, state_dim=18, action_dim=3, hidden=128, layers=2):
        super().__init__()
        self.rnn = nn.GRU(state_dim + action_dim, hidden, layers, batch_first=True)
        #self.out = nn.Linear(hidden, state_dim)
        self.head = nn.Sequential(
            nn.LayerNorm(hidden),
            nn.Linear(hidden, state_dim)
        )

    def forward(self, s, a):
        x = torch.cat([s, a], dim=-1)
        h, _ = self.rnn(x)
        return self.head(h)

# %%
# 20 CFC model setup

class CFC(nn.Module):
    def __init__(self, state_dim=18, action_dim=3, hidden=128):
        super().__init__()

        self.inp = nn.Linear(state_dim + action_dim, hidden)

        self.W_tau = nn.Linear(hidden, hidden)
        self.W_A = nn.Linear(hidden, hidden)
        self.W_B = nn.Linear(hidden, hidden)

        self.out = nn.Linear(hidden, state_dim)

    def forward(self, s, a):
        x = torch.cat([s, a], dim=-1)
        h = self.inp(x)

        tau = torch.sigmoid(self.W_tau(h))
        A = torch.tanh(self.W_A(h))
        B = self.W_B(h)

        # Closed form update
        h_new = (1 - tau) * A + tau * B

        return self.out(h_new)

# %%
# 21

def masked_mse(pred, target, mask):
    mask = mask.unsqueeze(-1)
    if mask.sum() == 0:
        print("Oh no")
    return ((pred - target) ** 2 * mask).sum() / mask.sum()

# %%
# 22 define our own train model function so we can control for training differences between models

from torch.cuda.amp import autocast, GradScaler

def train_model(model, train_loader, val_loader, epochs=30, lr=1e-3, device="cuda"):
    model.to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    scaler = GradScaler()

    best_val = float("inf")

    for epoch in range(epochs):
        model.train()

        for s, a, ns, mask in train_loader:
            s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)

            with autocast():
                pred = model(s, a)
                if torch.isnan(pred).any():
                    print("NaNs in prediction!")
                    print("s min/max:", s.min(), s.max())
                    print("a min/max:", a.min(), a.max())
                loss = masked_mse(pred, ns, mask)

            opt.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(opt)
            scaler.update()

        # Validation
        model.eval()
        with torch.no_grad():
            vals = []
            for s, a, ns, mask in val_loader:
                s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)
                pred = model(s, a)
                vals.append(masked_mse(pred, ns, mask).item())

            val_loss = np.mean(vals)

        print(f"Epoch {epoch}: val={val_loss:.5f}")

        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), "best.pt")

# %%
# 23

def rollout_rmse(model, loader, K, device="cuda"):
    model.eval()
    rmses = []

    with torch.no_grad():
        for s, a, ns, mask in loader:
            s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)

            cur = s.clone()

            for k in range(K):
                pred = model(cur, a)
                cur = pred  # teacher forcing OFF

            err = ((cur - ns) ** 2)[mask.unsqueeze(-1)].mean().sqrt()
            rmses.append(err.item())

    return np.mean(rmses)

# %%
# 24 function to load everything up and train a model

def run_experiment(train_seqs, val_seqs, test_seqs, model_type="gru"):
    train_ds = ICUDataset(train_seqs)
    val_ds = ICUDataset(val_seqs)
    test_ds = ICUDataset(test_seqs)

    train_loader = DataLoader(train_ds, batch_size=64, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_ds, batch_size=64, collate_fn=collate_fn)
    test_loader = DataLoader(test_ds, batch_size=64, collate_fn=collate_fn)

    if model_type == "gru":
        model = GRUModel()
    else:
        model = CFC()

    train_model(model, train_loader, val_loader)

    model.load_state_dict(torch.load("best.pt"))

    print("1-step RMSE:", rollout_rmse(model, test_loader, 1))
    print("3-step RMSE:", rollout_rmse(model, test_loader, 3))
    print("5-step RMSE:", rollout_rmse(model, test_loader, 5))

# %%
# 25 call experiment on both models

print("Training GRU")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="gru")

print("Training CFC")
run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc")
# Out:
# Training GRU
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:8: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9197, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(124000., device='cuda:0')
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(119195.8281, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9936, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(162356.4688, device='cuda:0')
# C:\Users\david\AppData\Local\Temp\ipykernel_14168\179922897.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(181353.2031, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(148615.2031, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(150810.1719, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(89271.8438, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(181000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(29999.9980, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9824, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(209999.9844, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(97074.4844, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(182002.2656, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(199289.2969, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(4000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(187874.1406, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9867, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(177733.7969, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9574, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180131.3750, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9863, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180331.2500, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(166689.7344, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(126834.6641, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(169917.1562, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(91150.6250, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(122553.1875, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(130536.6641, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9630, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(160615., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(191881.1250, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(195712.5000, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(213337.5000, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(147175.1719, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9853, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(119999.9922, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(138237.5000, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(157169.8906, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9824, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(144452.9844, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(186833.6562, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(171121.7500, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(182248.4531, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9265, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(217935., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9959, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(142650., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(146609.4688, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(94189.8594, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9867, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(197971.5469, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(216450., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(160135.5156, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(186367.5938, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(145301.4062, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(173827.7656, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9453, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(121000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(120999.9922, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9922, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(115296.2500, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(181000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(217016.2656, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9729, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(126161.6641, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(143998.7656, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(179329.5156, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(200365.1562, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(107806.1953, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9824, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(216455.3125, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(166702.6875, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(146209.9062, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(181748.9531, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(182000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(193100., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(4000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(181953.5312, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(192225.6719, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(131018., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(155799.1406, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9934, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(217325.7344, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(90338.0312, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9536, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(181998.3281, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(209524.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180849.3906, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(209999.9844, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(218308.0625, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(0.9210, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(189384.1562, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1.0000, device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(176332.1719, device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(180000., device='cuda:0')
# NaNs in prediction!
# s min/max: tensor(0., device='cuda:0') tensor(1., device='cuda:0')
# a min/max: tensor(0., device='cuda:0') tensor(42162.5000, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[148], line 4
#       1 # 25 call experiment on both models
#       3 print("Training GRU")
# ----> 4 run_experiment(train_seqs, val_seqs, test_seqs, model_type="gru")
#       6 print("Training CFC")
#       7 run_experiment(train_seqs, val_seqs, test_seqs, model_type="cfc")
#
# Cell In[122], line 17, in run_experiment(train_seqs, val_seqs, test_seqs, model_type)
#      14 else:
#      15     model = CFC()
# ---> 17 train_model(model, train_loader, val_loader)
#      19 model.load_state_dict(torch.load("best.pt"))
#      21 print("1-step RMSE:", rollout_rmse(model, test_loader, 1))
#
# Cell In[145], line 15, in train_model(model, train_loader, val_loader, epochs, lr, device)
#      12 for epoch in range(epochs):
#      13     model.train()
# ---> 15     for s, a, ns, mask in train_loader:
#      16         s, a, ns, mask = s.to(device), a.to(device), ns.to(device), mask.to(device)
#      18         with autocast():
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# Cell In[114], line 34, in collate_fn(batch)
#      31         out[i, :b.shape[0]] = b
#      32     return out
# ---> 34 states = pad([b["states"] for b in batch])
#      35 actions = pad([b["actions"] for b in batch])
#      36 next_states = pad([b["next_states"] for b in batch])
#
# Cell In[114], line 31, in collate_fn.<locals>.pad(x)
#      29 out = torch.zeros(len(batch), max_len, x[0].shape[-1])
#      30 for i, b in enumerate(x):
# ---> 31     out[i, :b.shape[0]] = b
#      32 return out
#
# KeyboardInterrupt:
